# %%
# libraries and settings
import gc
import pandas as pd
import numpy as np
from collections import defaultdict
from scipy.stats import pearsonr
from sklearn.linear_model import Ridge
import lightgbm as lgb
import optuna
import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_parquet('../data/input/train.parquet')
df_test = pd.read_parquet('../data/input/test.parquet')

# %%
# Clustering the features
X_cols = df_train.columns[df_train.columns.str.startswith('X')]
clusters = pd.Series(pd.read_csv('../data/intermediate/clusters.csv', index_col = 0).iloc[:,0])

# shuffle the features
clusters = clusters.sample(frac = 1, random_state = 42)

# sampling teh clusters
clusters_dict = defaultdict(list)

for c in np.unique(clusters):
    X = clusters[clusters == c]
    clusters_dict[c] = X.index.tolist()

total = 0
features_list = []
n_features = len(clusters)

while total < n_features:
    features = []
    for c in clusters_dict.keys():
        if len(clusters_dict[c]) > 0:
            features.append(clusters_dict[c][-1])
            clusters_dict[c].pop()
            total += 1
    features_list.append(features)
    features = list([])
    
while len(features_list[-1]) < 10:
    features_list.pop()

for i in range(len(features_list)):
    features_list[i] = ['bid_qty', 'ask_qty', 'buy_qty', 'sell_qty', 'volume'] + features_list[i]

# %%
""" **************** ENSEMBLE MODEL ****************** """
class LightGBMTimeSeriesEnsemble:
    def __init__(self, n_models, n_trials, feature_sets, alphas=None,
                 metric="l2", random_seed=42):
        """
        n_models  : number of base learners (e.g. 50)
        n_trials  : Optuna trials per learner
        alphas    : candidate ridge regularization strengths
        metric    : LightGBM eval metric (for early stopping)
        """
        self.n_models = n_models
        self.n_trials = n_trials
        self.feature_sets = feature_sets
        self.metric = metric
        self.alphas = alphas if alphas is not None else np.logspace(-2, 5, 30)
        self.seed = random_seed

        self.best_params_list = []
        self.best_iterations = []
        self.models = []
        self.ridge = None
        self.best_alpha = None

    def _optuna_objective(self, trial, X_tr, y_tr, X_val, y_val):
        params = {
            'objective': 'regression',
            'metric': 'rmse',  
            'verbosity': -1,
            'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.1, log=True),
            'num_leaves': trial.suggest_int('num_leaves', 16, 64),
            'max_depth': trial.suggest_int('max_depth', 2, 6),
            'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 100),
            'feature_fraction': trial.suggest_float('feature_fraction', 0.1, 0.5),
            'bagging_fraction': trial.suggest_float('bagging_fraction', 0.2, 0.6),
            'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
            'lambda_l1': trial.suggest_float('lambda_l1', 0.0, 5.0),
            'lambda_l2': trial.suggest_float('lambda_l2', 0.0, 5.0),
            'num_boost_round': trial.suggest_int('num_boost_round', 200,500),
            'early_stopping_rounds': 50
        }
        model = lgb.train(
            params,
            lgb.Dataset(X_tr, y_tr),
            valid_sets=[lgb.Dataset(X_val, y_val)]
        )
        pred = model.predict(X_val)
        corr, _ = pearsonr(pred, y_val)
        return -corr

    def fit(self, X_train, y_train, X_val, y_val):
        """
        1) Fit each base model on X_train[i::n] versus y_train[i::n] with Optuna tuning.
        Next steps are carried out in the fit_ridge function:
        2) Make predictions of each base model on *full* X_train => (n_samples_train x n_models)
        3) Ridge-fit on (train_preds, y_train)
        4) Select alpha by evaluating ridge on full X_val predictions
        """
        self.models = []
        self.best_params_list = []
        self.best_iterations = []

        for j in range(len(self.feature_sets)):
            for i in range(self.n_models):
                print(f'Training on feature set {j+1}/{len(self.feature_sets)}, model {i+1}/{self.n_models}')
                
                Xt = X_train.iloc[i::self.n_models][self.feature_sets[j]]
                yt = y_train.iloc[i::self.n_models]
                Xv = X_val.iloc[i::self.n_models][self.feature_sets[j]]
                yv = y_val.iloc[i::self.n_models]
    
                # Tune
                sampler = optuna.samplers.TPESampler(seed=self.seed)
                study = optuna.create_study(direction='minimize', sampler=sampler)
                study.optimize(
                    lambda trial: self._optuna_objective(trial, Xt, yt, Xv, yv),
                    n_trials=self.n_trials,
                )
                best_params = study.best_params
                best_params['seed'] = self.seed
                
    
                # Train model with best params
                model = lgb.train(
                    {
                    **best_params, 
                    'objective':'regression',
                    'metric':self.metric,
                    'verbosity':-1, 
                    'early_stopping_rounds': 50
                    },
                    lgb.Dataset(Xt, yt),
                    valid_sets=[lgb.Dataset(Xv, yv)]
                )
                best_params['num_boost_round'] = model.best_iteration
                self.best_params_list.append(best_params)
                self.best_iterations.append(model.best_iteration)
                self.models.append(model)

        self.fit_ridge(X_train, y_train, X_val, y_val, self.alphas)
        
        
    def fit_ridge(self, X_train, y_train, X_val, y_val, alphas):
        """
        1) Make predictions of each base model on *full* X_train => (n_samples_train x n_models)
        2) Ridge-fit on (train_preds, y_train)
        3) Select alpha by evaluating ridge on full X_val predictions
        """
        train_preds = []
        val_preds   = []
        idx = 0

         # --- predictions on full training and validation set ---
        for subset in self.feature_sets:
            for _ in range(self.n_models):
                m  = self.models[idx]
                it = self.best_iterations[idx]
                train_preds.append(m.predict(X_train[subset], num_iteration=it))
                val_preds.append(m.predict(X_val[subset],   num_iteration=it))
                idx += 1
        
        train_stack = np.column_stack(train_preds)
        val_stack   = np.column_stack(val_preds)
       
        self.alphas = alphas
        best_corr = -np.inf
        for a in self.alphas:
            r = Ridge(alpha=a)
            r.fit(train_stack, y_train)
            corr, _ = pearsonr(r.predict(val_stack), y_val)
            print(f' ridge alpha: {a:.5f}, val corr: {corr:.5f}')
            if corr > best_corr:
                best_corr, self.best_alpha, self.ridge = corr, a, r

        print(f'Best ridge alpha: {self.best_alpha:.5f}, val corr: {best_corr:.5f}')
    
    
    def refit_full(self, X_full, y_full):
        """
        Retrain base models and the ridge regression model on full data using best params and alpha.
        """
        self.models = []
        idx = 0
        for subset in self.feature_sets:
            for _ in range(self.n_models):
                print(f'Refitting model {idx+1}/{self.n_models*len(self.feature_sets)} on full data...')
                params  = self.best_params_list[idx]
                model = lgb.train(
                    {
                    **params,  
                    'objective':'regression',
                    'metric':self.metric,
                    'verbosity':-1
                    },
                    lgb.Dataset(X_full[subset], y_full)
                )
                self.models.append(model)
                idx += 1
        
        preds = []
        idx = 0
         # --- predictions on full dataset
        for subset in self.feature_sets:
            for _ in range(self.n_models):
                m  = self.models[idx]
                it = self.best_iterations[idx]
                preds.append(m.predict(X_full[subset], num_iteration=it))
                idx += 1
                
        full_stack = stack = np.column_stack(preds)       
        self.ridge = Ridge(alpha=self.best_alpha)
        self.ridge.fit(full_stack, y_full)

    def predict(self, X):
        """
        Predict stacked output on full dataset X
        """
        preds = []
        idx = 0
        for subset in self.feature_sets:
            for _ in range(self.n_models):
                m  = self.models[idx]
                it = self.best_iterations[idx]
                preds.append(m.predict(X[subset], num_iteration=it))
                idx += 1
        stack = np.column_stack(preds)
        
        return self.ridge.predict(stack)

# %%
df_train.sort_index(inplace = True)
n_train = round(df_train.shape[0]*0.8)
X_train = df_train.iloc[:n_train].drop(columns = ['label'])
X_val = df_train.iloc[n_train:].drop(columns = ['label'])
y_train = df_train.iloc[:n_train]['label'] 
y_val = df_train.iloc[n_train:]['label'] 

ensemble = LightGBMTimeSeriesEnsemble(n_models=5, n_trials=50, feature_sets=features_list)
ensemble.fit(X_train, y_train, X_val, y_val)
# Out:
# [I 2025-08-19 14:47:32,047] A new study created in memory with name: no-name-94a59bad-11a4-4401-87c3-51df3e531bc1
# Training on feature set 1/12, model 1/5
# [I 2025-08-19 14:47:33,925] Trial 0 finished with value: -0.08080226745370152 and parameters: {'learning_rate': 0.015355286838886862, 'num_leaves': 62, 'max_depth': 5, 'min_data_in_leaf': 64, 'feature_fraction': 0.1624074561769746, 'bagging_fraction': 0.26239780813448105, 'bagging_freq': 1, 'lambda_l1': 4.330880728874676, 'lambda_l2': 3.005575058716044, 'num_boost_round': 413}. Best is trial 0 with value: -0.08080226745370152.
# [I 2025-08-19 14:47:35,966] Trial 1 finished with value: -0.0829087427784682 and parameters: {'learning_rate': 0.005318033256270142, 'num_leaves': 63, 'max_depth': 6, 'min_data_in_leaf': 29, 'feature_fraction': 0.17272998688284025, 'bagging_fraction': 0.27336180394137355, 'bagging_freq': 4, 'lambda_l1': 2.6237821581611893, 'lambda_l2': 2.1597250932105787, 'num_boost_round': 287}. Best is trial 1 with value: -0.0829087427784682.
# [I 2025-08-19 14:47:37,512] Trial 2 finished with value: -0.08354512870665791 and parameters: {'learning_rate': 0.03126143958203108, 'num_leaves': 22, 'max_depth': 3, 'min_data_in_leaf': 43, 'feature_fraction': 0.28242799368681437, 'bagging_fraction': 0.5140703845572054, 'bagging_freq': 2, 'lambda_l1': 2.571172192068058, 'lambda_l2': 2.9620728443102124, 'num_boost_round': 213}. Best is trial 2 with value: -0.08354512870665791.
# [I 2025-08-19 14:47:38,839] Trial 3 finished with value: -0.06076607327058087 and parameters: {'learning_rate': 0.030860579740535368, 'num_leaves': 24, 'max_depth': 2, 'min_data_in_leaf': 96, 'feature_fraction': 0.4862528132298237, 'bagging_fraction': 0.5233589392465845, 'bagging_freq': 4, 'lambda_l1': 0.48836057003191935, 'lambda_l2': 3.4211651325607844, 'num_boost_round': 332}. Best is trial 2 with value: -0.08354512870665791.
# [I 2025-08-19 14:47:40,708] Trial 4 finished with value: -0.062384301610182734 and parameters: {'learning_rate': 0.007206848764305203, 'num_leaves': 40, 'max_depth': 2, 'min_data_in_leaf': 92, 'feature_fraction': 0.20351199264000677, 'bagging_fraction': 0.46500891374159276, 'bagging_freq': 4, 'lambda_l1': 2.600340105889054, 'lambda_l2': 2.7335513967163982, 'num_boost_round': 255}. Best is trial 2 with value: -0.08354512870665791.
# [I 2025-08-19 14:47:42,622] Trial 5 finished with value: -0.1009517049601756 and parameters: {'learning_rate': 0.09129115219600122, 'num_leaves': 53, 'max_depth': 6, 'min_data_in_leaf': 91, 'feature_fraction': 0.3391599915244341, 'bagging_fraction': 0.5687496940092467, 'bagging_freq': 1, 'lambda_l1': 0.979914312095726, 'lambda_l2': 0.22613644455269033, 'num_boost_round': 297}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:47:44,799] Trial 6 finished with value: -0.07309619350147067 and parameters: {'learning_rate': 0.016019568611465234, 'num_leaves': 29, 'max_depth': 6, 'min_data_in_leaf': 42, 'feature_fraction': 0.2123738038749523, 'bagging_fraction': 0.4170784332632994, 'bagging_freq': 2, 'lambda_l1': 4.010984903770199, 'lambda_l2': 0.3727532183988541, 'num_boost_round': 497}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:47:46,373] Trial 7 finished with value: -0.05061501334540624 and parameters: {'learning_rate': 0.05054562991054155, 'num_leaves': 25, 'max_depth': 2, 'min_data_in_leaf': 84, 'feature_fraction': 0.38274293753904687, 'bagging_fraction': 0.4916028672163949, 'bagging_freq': 8, 'lambda_l1': 0.3702232586704518, 'lambda_l2': 1.7923286427213632, 'num_boost_round': 234}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:47:47,968] Trial 8 finished with value: -0.07133320298209095 and parameters: {'learning_rate': 0.06635802485202448, 'num_leaves': 46, 'max_depth': 3, 'min_data_in_leaf': 15, 'feature_fraction': 0.2243929286862649, 'bagging_fraction': 0.33007332881069884, 'bagging_freq': 8, 'lambda_l1': 3.1877873567760657, 'lambda_l2': 4.436063712881633, 'num_boost_round': 342}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:47:50,603] Trial 9 finished with value: -0.08769329735201553 and parameters: {'learning_rate': 0.007154276249073926, 'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 61, 'feature_fraction': 0.40838687198182444, 'bagging_fraction': 0.3975182385457563, 'bagging_freq': 6, 'lambda_l1': 2.137705091792748, 'lambda_l2': 0.12709563372047594, 'num_boost_round': 232}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:47:52,287] Trial 10 finished with value: -0.041171294796234985 and parameters: {'learning_rate': 0.09404233974335759, 'num_leaves': 53, 'max_depth': 5, 'min_data_in_leaf': 75, 'feature_fraction': 0.3480689811822219, 'bagging_fraction': 0.5630659181130071, 'bagging_freq': 10, 'lambda_l1': 1.42539945756007, 'lambda_l2': 1.0623493620999978, 'num_boost_round': 411}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:47:55,309] Trial 11 finished with value: -0.08462004320438907 and parameters: {'learning_rate': 0.011589164115192143, 'num_leaves': 51, 'max_depth': 5, 'min_data_in_leaf': 64, 'feature_fraction': 0.4399304491686939, 'bagging_fraction': 0.3448589233350371, 'bagging_freq': 6, 'lambda_l1': 1.2517516537157303, 'lambda_l2': 0.03882400016731771, 'num_boost_round': 289}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:47:57,576] Trial 12 finished with value: -0.07862374829258036 and parameters: {'learning_rate': 0.009490326093879354, 'num_leaves': 41, 'max_depth': 6, 'min_data_in_leaf': 74, 'feature_fraction': 0.380465038157504, 'bagging_fraction': 0.5862778301767895, 'bagging_freq': 6, 'lambda_l1': 1.4358090189338917, 'lambda_l2': 0.9810199349952932, 'num_boost_round': 201}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:47:59,198] Trial 13 finished with value: -0.09926612299830923 and parameters: {'learning_rate': 0.02711641797158029, 'num_leaves': 54, 'max_depth': 4, 'min_data_in_leaf': 55, 'feature_fraction': 0.29883415744434105, 'bagging_fraction': 0.3925032587634266, 'bagging_freq': 8, 'lambda_l1': 1.655391399090783, 'lambda_l2': 0.9262986969204228, 'num_boost_round': 281}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:48:00,860] Trial 14 finished with value: -0.09600891679114365 and parameters: {'learning_rate': 0.04469383532079373, 'num_leaves': 57, 'max_depth': 4, 'min_data_in_leaf': 46, 'feature_fraction': 0.297777914554466, 'bagging_fraction': 0.43107844660254585, 'bagging_freq': 8, 'lambda_l1': 0.018257903686377586, 'lambda_l2': 1.1638226553209554, 'num_boost_round': 294}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:48:02,240] Trial 15 finished with value: -0.03735805467703425 and parameters: {'learning_rate': 0.09494545293532243, 'num_leaves': 38, 'max_depth': 4, 'min_data_in_leaf': 52, 'feature_fraction': 0.10189604786123588, 'bagging_fraction': 0.20836542659336157, 'bagging_freq': 10, 'lambda_l1': 0.7824026000267326, 'lambda_l2': 1.6399266073423122, 'num_boost_round': 380}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:48:03,566] Trial 16 finished with value: -0.05706074228167908 and parameters: {'learning_rate': 0.022765671967488764, 'num_leaves': 58, 'max_depth': 3, 'min_data_in_leaf': 29, 'feature_fraction': 0.33256316158254373, 'bagging_fraction': 0.3721808331614443, 'bagging_freq': 9, 'lambda_l1': 1.8559795265992625, 'lambda_l2': 0.6723760226759967, 'num_boost_round': 320}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:48:05,175] Trial 17 finished with value: -0.08847836952321436 and parameters: {'learning_rate': 0.05883470569201959, 'num_leaves': 33, 'max_depth': 4, 'min_data_in_leaf': 77, 'feature_fraction': 0.25079838830655143, 'bagging_fraction': 0.4679329266895621, 'bagging_freq': 7, 'lambda_l1': 3.416327295322436, 'lambda_l2': 1.6190592292360888, 'num_boost_round': 376}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:48:06,700] Trial 18 finished with value: -0.07294012892189353 and parameters: {'learning_rate': 0.03678431111150485, 'num_leaves': 45, 'max_depth': 5, 'min_data_in_leaf': 86, 'feature_fraction': 0.32895869105376524, 'bagging_fraction': 0.3128196155113065, 'bagging_freq': 3, 'lambda_l1': 1.0209149318019777, 'lambda_l2': 4.840887258517274, 'num_boost_round': 279}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:48:08,157] Trial 19 finished with value: -0.08682152375504673 and parameters: {'learning_rate': 0.019900771215334668, 'num_leaves': 55, 'max_depth': 3, 'min_data_in_leaf': 31, 'feature_fraction': 0.26166750169446507, 'bagging_fraction': 0.5485534957490615, 'bagging_freq': 5, 'lambda_l1': 4.906565433791467, 'lambda_l2': 0.6357192100443614, 'num_boost_round': 258}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:48:09,605] Trial 20 finished with value: -0.07523853053900939 and parameters: {'learning_rate': 0.07228405546391048, 'num_leaves': 47, 'max_depth': 4, 'min_data_in_leaf': 10, 'feature_fraction': 0.45349278045714214, 'bagging_fraction': 0.4548849658296108, 'bagging_freq': 1, 'lambda_l1': 1.6618382268736895, 'lambda_l2': 3.6738901466096086, 'num_boost_round': 491}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:48:10,991] Trial 21 finished with value: -0.0610115808554679 and parameters: {'learning_rate': 0.044012946770300605, 'num_leaves': 57, 'max_depth': 4, 'min_data_in_leaf': 52, 'feature_fraction': 0.3025995654341708, 'bagging_fraction': 0.4149776428041753, 'bagging_freq': 8, 'lambda_l1': 0.14368609301383106, 'lambda_l2': 1.1166172221317385, 'num_boost_round': 306}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:48:12,680] Trial 22 finished with value: -0.07016789197767072 and parameters: {'learning_rate': 0.023550788218825596, 'num_leaves': 60, 'max_depth': 4, 'min_data_in_leaf': 41, 'feature_fraction': 0.30123644861398574, 'bagging_fraction': 0.43432595599239915, 'bagging_freq': 7, 'lambda_l1': 0.013192515344812361, 'lambda_l2': 1.3767584338635126, 'num_boost_round': 360}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:48:14,141] Trial 23 finished with value: -0.026733842569759178 and parameters: {'learning_rate': 0.04391048399828839, 'num_leaves': 17, 'max_depth': 3, 'min_data_in_leaf': 57, 'feature_fraction': 0.3608775194487168, 'bagging_fraction': 0.5997013952810174, 'bagging_freq': 9, 'lambda_l1': 0.7474862433302166, 'lambda_l2': 0.6053019355586241, 'num_boost_round': 309}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:48:15,824] Trial 24 finished with value: -0.08166253651421276 and parameters: {'learning_rate': 0.029906627380531424, 'num_leaves': 64, 'max_depth': 5, 'min_data_in_leaf': 46, 'feature_fraction': 0.30892426309174487, 'bagging_fraction': 0.37359592654370427, 'bagging_freq': 7, 'lambda_l1': 2.0560241181078682, 'lambda_l2': 2.155069595588398, 'num_boost_round': 259}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:48:17,393] Trial 25 finished with value: -0.07804587883061005 and parameters: {'learning_rate': 0.07914727319682481, 'num_leaves': 55, 'max_depth': 4, 'min_data_in_leaf': 100, 'feature_fraction': 0.259676290902053, 'bagging_fraction': 0.4982181590884207, 'bagging_freq': 9, 'lambda_l1': 0.8462046003240782, 'lambda_l2': 0.8821629260449415, 'num_boost_round': 276}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:48:19,380] Trial 26 finished with value: -0.04332811224649139 and parameters: {'learning_rate': 0.060665606175309986, 'num_leaves': 49, 'max_depth': 6, 'min_data_in_leaf': 67, 'feature_fraction': 0.40245625401772733, 'bagging_fraction': 0.29384264966919865, 'bagging_freq': 5, 'lambda_l1': 0.4854742017499448, 'lambda_l2': 0.2992930497336913, 'num_boost_round': 306}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:48:20,904] Trial 27 finished with value: -0.09099195582023756 and parameters: {'learning_rate': 0.03861787625915231, 'num_leaves': 59, 'max_depth': 4, 'min_data_in_leaf': 49, 'feature_fraction': 0.28363237674886566, 'bagging_fraction': 0.3753849262916704, 'bagging_freq': 8, 'lambda_l1': 1.2757985386722117, 'lambda_l2': 2.015564873437141, 'num_boost_round': 231}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:48:22,310] Trial 28 finished with value: -0.0740664086489292 and parameters: {'learning_rate': 0.055396498971495206, 'num_leaves': 53, 'max_depth': 4, 'min_data_in_leaf': 35, 'feature_fraction': 0.3285484931124335, 'bagging_fraction': 0.23656899917027574, 'bagging_freq': 7, 'lambda_l1': 1.1006071151103187, 'lambda_l2': 1.313578976708031, 'num_boost_round': 358}. Best is trial 5 with value: -0.1009517049601756.
# [I 2025-08-19 14:48:23,983] Trial 29 finished with value: -0.10854623352829212 and parameters: {'learning_rate': 0.017115849701535964, 'num_leaves': 60, 'max_depth': 5, 'min_data_in_leaf': 70, 'feature_fraction': 0.14756782424846654, 'bagging_fraction': 0.5478926911227507, 'bagging_freq': 1, 'lambda_l1': 0.0071613962970807805, 'lambda_l2': 2.3675133438646387, 'num_boost_round': 332}. Best is trial 29 with value: -0.10854623352829212.
# [I 2025-08-19 14:48:25,397] Trial 30 finished with value: -0.04591705455222574 and parameters: {'learning_rate': 0.013696554688785278, 'num_leaves': 62, 'max_depth': 6, 'min_data_in_leaf': 70, 'feature_fraction': 0.106478137647976, 'bagging_fraction': 0.5539466513200291, 'bagging_freq': 1, 'lambda_l1': 1.6927238385567844, 'lambda_l2': 3.775663283784305, 'num_boost_round': 407}. Best is trial 29 with value: -0.10854623352829212.
# [I 2025-08-19 14:48:27,469] Trial 31 finished with value: -0.07025940917624172 and parameters: {'learning_rate': 0.026781580699616458, 'num_leaves': 56, 'max_depth': 5, 'min_data_in_leaf': 60, 'feature_fraction': 0.15251748587295116, 'bagging_fraction': 0.5262700165670262, 'bagging_freq': 2, 'lambda_l1': 0.2690247412447115, 'lambda_l2': 2.637419108685606, 'num_boost_round': 333}. Best is trial 29 with value: -0.10854623352829212.
# [I 2025-08-19 14:48:29,917] Trial 32 finished with value: -0.09896742511642598 and parameters: {'learning_rate': 0.017213932246288824, 'num_leaves': 61, 'max_depth': 6, 'min_data_in_leaf': 81, 'feature_fraction': 0.1476494163893223, 'bagging_fraction': 0.56787858404782, 'bagging_freq': 1, 'lambda_l1': 0.6707953302922057, 'lambda_l2': 2.2980145236795697, 'num_boost_round': 294}. Best is trial 29 with value: -0.10854623352829212.
# [I 2025-08-19 14:48:32,200] Trial 33 finished with value: -0.06187779981636354 and parameters: {'learning_rate': 0.01799343238158139, 'num_leaves': 61, 'max_depth': 6, 'min_data_in_leaf': 84, 'feature_fraction': 0.14813719914809137, 'bagging_fraction': 0.5803352379816823, 'bagging_freq': 1, 'lambda_l1': 0.6049863324783084, 'lambda_l2': 3.1116916273861417, 'num_boost_round': 458}. Best is trial 29 with value: -0.10854623352829212.
# [I 2025-08-19 14:48:35,477] Trial 34 finished with value: -0.08787159246670888 and parameters: {'learning_rate': 0.01238992149023283, 'num_leaves': 64, 'max_depth': 6, 'min_data_in_leaf': 89, 'feature_fraction': 0.18820961620600724, 'bagging_fraction': 0.5375598603642187, 'bagging_freq': 3, 'lambda_l1': 0.9983985284308874, 'lambda_l2': 2.424854810677134, 'num_boost_round': 319}. Best is trial 29 with value: -0.10854623352829212.
# [I 2025-08-19 14:48:38,813] Trial 35 finished with value: -0.08455058531036468 and parameters: {'learning_rate': 0.010449902041825311, 'num_leaves': 43, 'max_depth': 6, 'min_data_in_leaf': 78, 'feature_fraction': 0.1321296829729715, 'bagging_fraction': 0.5055334925684358, 'bagging_freq': 3, 'lambda_l1': 2.1521718587289227, 'lambda_l2': 2.2830251464216658, 'num_boost_round': 270}. Best is trial 29 with value: -0.10854623352829212.
# [I 2025-08-19 14:48:40,919] Trial 36 finished with value: -0.08447149446242912 and parameters: {'learning_rate': 0.015630195700765577, 'num_leaves': 53, 'max_depth': 5, 'min_data_in_leaf': 93, 'feature_fraction': 0.17457871808187495, 'bagging_fraction': 0.5715188221326677, 'bagging_freq': 2, 'lambda_l1': 0.5068869010354167, 'lambda_l2': 2.9624959017943233, 'num_boost_round': 325}. Best is trial 29 with value: -0.10854623352829212.
# [I 2025-08-19 14:48:44,379] Trial 37 finished with value: -0.08408683463202919 and parameters: {'learning_rate': 0.008414443089024802, 'num_leaves': 60, 'max_depth': 6, 'min_data_in_leaf': 80, 'feature_fraction': 0.23493047370714532, 'bagging_fraction': 0.4835703839930775, 'bagging_freq': 1, 'lambda_l1': 1.5753205512948523, 'lambda_l2': 3.251318752239433, 'num_boost_round': 294}. Best is trial 29 with value: -0.10854623352829212.
# [I 2025-08-19 14:48:46,518] Trial 38 finished with value: -0.08347618268362561 and parameters: {'learning_rate': 0.01894988069444306, 'num_leaves': 36, 'max_depth': 5, 'min_data_in_leaf': 69, 'feature_fraction': 0.13014105254799044, 'bagging_fraction': 0.5987795598068703, 'bagging_freq': 2, 'lambda_l1': 0.3454916183037688, 'lambda_l2': 1.947491346098709, 'num_boost_round': 244}. Best is trial 29 with value: -0.10854623352829212.
# [I 2025-08-19 14:48:50,224] Trial 39 finished with value: -0.08247965006431647 and parameters: {'learning_rate': 0.005597812709393509, 'num_leaves': 62, 'max_depth': 6, 'min_data_in_leaf': 98, 'feature_fraction': 0.19688570002658112, 'bagging_fraction': 0.5328007359722101, 'bagging_freq': 3, 'lambda_l1': 3.1571988820048897, 'lambda_l2': 0.4158790815635746, 'num_boost_round': 344}. Best is trial 29 with value: -0.10854623352829212.
# [I 2025-08-19 14:48:52,315] Trial 40 finished with value: -0.07094179558206935 and parameters: {'learning_rate': 0.01409850623553206, 'num_leaves': 48, 'max_depth': 5, 'min_data_in_leaf': 92, 'feature_fraction': 0.17696761992653756, 'bagging_fraction': 0.5125730214260555, 'bagging_freq': 4, 'lambda_l1': 2.3018773859050077, 'lambda_l2': 2.739161746767582, 'num_boost_round': 382}. Best is trial 29 with value: -0.10854623352829212.
# [I 2025-08-19 14:48:53,757] Trial 41 finished with value: -0.10942808833143514 and parameters: {'learning_rate': 0.026054452512667477, 'num_leaves': 58, 'max_depth': 4, 'min_data_in_leaf': 37, 'feature_fraction': 0.2791261687812442, 'bagging_fraction': 0.39670286983357517, 'bagging_freq': 1, 'lambda_l1': 0.12404182372388961, 'lambda_l2': 1.3577078133862708, 'num_boost_round': 297}. Best is trial 41 with value: -0.10942808833143514.
# [I 2025-08-19 14:48:55,633] Trial 42 finished with value: -0.08905219571862782 and parameters: {'learning_rate': 0.0255887423878816, 'num_leaves': 52, 'max_depth': 5, 'min_data_in_leaf': 18, 'feature_fraction': 0.22917511047145334, 'bagging_fraction': 0.39165288165733836, 'bagging_freq': 1, 'lambda_l1': 0.6463775532935014, 'lambda_l2': 1.6799161474185746, 'num_boost_round': 268}. Best is trial 41 with value: -0.10942808833143514.
# [I 2025-08-19 14:48:57,724] Trial 43 finished with value: -0.07925908365015304 and parameters: {'learning_rate': 0.017186453706532396, 'num_leaves': 59, 'max_depth': 6, 'min_data_in_leaf': 81, 'feature_fraction': 0.37277693945447704, 'bagging_fraction': 0.35266272703256774, 'bagging_freq': 2, 'lambda_l1': 0.34868478727324687, 'lambda_l2': 1.4816116604833216, 'num_boost_round': 290}. Best is trial 41 with value: -0.10942808833143514.
# [I 2025-08-19 14:48:59,605] Trial 44 finished with value: -0.04004268970432891 and parameters: {'learning_rate': 0.030867872644607976, 'num_leaves': 54, 'max_depth': 5, 'min_data_in_leaf': 38, 'feature_fraction': 0.4964726713867945, 'bagging_fraction': 0.4555742741013469, 'bagging_freq': 1, 'lambda_l1': 0.9473742603214664, 'lambda_l2': 0.7256006283688852, 'num_boost_round': 307}. Best is trial 41 with value: -0.10942808833143514.
# [I 2025-08-19 14:49:01,473] Trial 45 finished with value: -0.09140740528332031 and parameters: {'learning_rate': 0.020732561951964063, 'num_leaves': 62, 'max_depth': 4, 'min_data_in_leaf': 73, 'feature_fraction': 0.276837356292589, 'bagging_fraction': 0.5590742124063419, 'bagging_freq': 2, 'lambda_l1': 1.2475106105999487, 'lambda_l2': 0.2443307688644063, 'num_boost_round': 246}. Best is trial 41 with value: -0.10942808833143514.
# [I 2025-08-19 14:49:03,325] Trial 46 finished with value: -0.09922763326972825 and parameters: {'learning_rate': 0.03607658011500763, 'num_leaves': 50, 'max_depth': 3, 'min_data_in_leaf': 63, 'feature_fraction': 0.21254726343166122, 'bagging_fraction': 0.4114835130156057, 'bagging_freq': 1, 'lambda_l1': 0.19685505379091595, 'lambda_l2': 0.018142418353364997, 'num_boost_round': 219}. Best is trial 41 with value: -0.10942808833143514.
# [I 2025-08-19 14:49:05,135] Trial 47 finished with value: -0.08748494397644707 and parameters: {'learning_rate': 0.025634103138331452, 'num_leaves': 50, 'max_depth': 2, 'min_data_in_leaf': 63, 'feature_fraction': 0.22123710528338586, 'bagging_fraction': 0.4182753279106174, 'bagging_freq': 2, 'lambda_l1': 0.1857273159105009, 'lambda_l2': 0.06002526751024986, 'num_boost_round': 214}. Best is trial 41 with value: -0.10942808833143514.
# [I 2025-08-19 14:49:07,113] Trial 48 finished with value: -0.07973961004162802 and parameters: {'learning_rate': 0.03780909671708029, 'num_leaves': 42, 'max_depth': 3, 'min_data_in_leaf': 53, 'feature_fraction': 0.24308120084772597, 'bagging_fraction': 0.3394536027541903, 'bagging_freq': 3, 'lambda_l1': 0.20331866920971547, 'lambda_l2': 0.5213155136026495, 'num_boost_round': 215}. Best is trial 41 with value: -0.10942808833143514.
# [I 2025-08-19 14:49:08,541] Trial 49 finished with value: -0.11374972113840821 and parameters: {'learning_rate': 0.035453726866509515, 'num_leaves': 51, 'max_depth': 3, 'min_data_in_leaf': 20, 'feature_fraction': 0.2741715170321239, 'bagging_fraction': 0.3184672526143487, 'bagging_freq': 1, 'lambda_l1': 0.45057850082848916, 'lambda_l2': 0.7956214449265218, 'num_boost_round': 335}. Best is trial 49 with value: -0.11374972113840821.
# Training on feature set 1/12, model 2/5
# [I 2025-08-19 14:49:10,237] A new study created in memory with name: no-name-2a66fce1-b68f-4873-af17-66419fd7296d
# [I 2025-08-19 14:49:11,710] Trial 0 finished with value: -0.07518809983599434 and parameters: {'learning_rate': 0.015355286838886862, 'num_leaves': 62, 'max_depth': 5, 'min_data_in_leaf': 64, 'feature_fraction': 0.1624074561769746, 'bagging_fraction': 0.26239780813448105, 'bagging_freq': 1, 'lambda_l1': 4.330880728874676, 'lambda_l2': 3.005575058716044, 'num_boost_round': 413}. Best is trial 0 with value: -0.07518809983599434.
# [I 2025-08-19 14:49:14,105] Trial 1 finished with value: -0.09776442774770872 and parameters: {'learning_rate': 0.005318033256270142, 'num_leaves': 63, 'max_depth': 6, 'min_data_in_leaf': 29, 'feature_fraction': 0.17272998688284025, 'bagging_fraction': 0.27336180394137355, 'bagging_freq': 4, 'lambda_l1': 2.6237821581611893, 'lambda_l2': 2.1597250932105787, 'num_boost_round': 287}. Best is trial 1 with value: -0.09776442774770872.
# [I 2025-08-19 14:49:15,925] Trial 2 finished with value: -0.10733999709173266 and parameters: {'learning_rate': 0.03126143958203108, 'num_leaves': 22, 'max_depth': 3, 'min_data_in_leaf': 43, 'feature_fraction': 0.28242799368681437, 'bagging_fraction': 0.5140703845572054, 'bagging_freq': 2, 'lambda_l1': 2.571172192068058, 'lambda_l2': 2.9620728443102124, 'num_boost_round': 213}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:17,547] Trial 3 finished with value: -0.06963170485074971 and parameters: {'learning_rate': 0.030860579740535368, 'num_leaves': 24, 'max_depth': 2, 'min_data_in_leaf': 96, 'feature_fraction': 0.4862528132298237, 'bagging_fraction': 0.5233589392465845, 'bagging_freq': 4, 'lambda_l1': 0.48836057003191935, 'lambda_l2': 3.4211651325607844, 'num_boost_round': 332}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:19,568] Trial 4 finished with value: -0.07523265539444712 and parameters: {'learning_rate': 0.007206848764305203, 'num_leaves': 40, 'max_depth': 2, 'min_data_in_leaf': 92, 'feature_fraction': 0.20351199264000677, 'bagging_fraction': 0.46500891374159276, 'bagging_freq': 4, 'lambda_l1': 2.600340105889054, 'lambda_l2': 2.7335513967163982, 'num_boost_round': 255}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:21,611] Trial 5 finished with value: -0.1036739515143357 and parameters: {'learning_rate': 0.09129115219600122, 'num_leaves': 53, 'max_depth': 6, 'min_data_in_leaf': 91, 'feature_fraction': 0.3391599915244341, 'bagging_fraction': 0.5687496940092467, 'bagging_freq': 1, 'lambda_l1': 0.979914312095726, 'lambda_l2': 0.22613644455269033, 'num_boost_round': 297}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:23,598] Trial 6 finished with value: -0.08026932454413431 and parameters: {'learning_rate': 0.016019568611465234, 'num_leaves': 29, 'max_depth': 6, 'min_data_in_leaf': 42, 'feature_fraction': 0.2123738038749523, 'bagging_fraction': 0.4170784332632994, 'bagging_freq': 2, 'lambda_l1': 4.010984903770199, 'lambda_l2': 0.3727532183988541, 'num_boost_round': 497}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:25,006] Trial 7 finished with value: -0.08379530821962733 and parameters: {'learning_rate': 0.05054562991054155, 'num_leaves': 25, 'max_depth': 2, 'min_data_in_leaf': 84, 'feature_fraction': 0.38274293753904687, 'bagging_fraction': 0.4916028672163949, 'bagging_freq': 8, 'lambda_l1': 0.3702232586704518, 'lambda_l2': 1.7923286427213632, 'num_boost_round': 234}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:26,260] Trial 8 finished with value: -0.083221076143905 and parameters: {'learning_rate': 0.06635802485202448, 'num_leaves': 46, 'max_depth': 3, 'min_data_in_leaf': 15, 'feature_fraction': 0.2243929286862649, 'bagging_fraction': 0.33007332881069884, 'bagging_freq': 8, 'lambda_l1': 3.1877873567760657, 'lambda_l2': 4.436063712881633, 'num_boost_round': 342}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:28,034] Trial 9 finished with value: -0.07670522611654994 and parameters: {'learning_rate': 0.007154276249073926, 'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 61, 'feature_fraction': 0.40838687198182444, 'bagging_fraction': 0.3975182385457563, 'bagging_freq': 6, 'lambda_l1': 2.137705091792748, 'lambda_l2': 0.12709563372047594, 'num_boost_round': 232}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:29,430] Trial 10 finished with value: -0.08999963568692436 and parameters: {'learning_rate': 0.02918002891674274, 'num_leaves': 16, 'max_depth': 4, 'min_data_in_leaf': 41, 'feature_fraction': 0.28599562510310794, 'bagging_fraction': 0.5630659181130071, 'bagging_freq': 10, 'lambda_l1': 1.6267999898564243, 'lambda_l2': 4.734809381950747, 'num_boost_round': 203}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:30,829] Trial 11 finished with value: -0.08883281325579179 and parameters: {'learning_rate': 0.09819779650749241, 'num_leaves': 37, 'max_depth': 4, 'min_data_in_leaf': 73, 'feature_fraction': 0.3079182573731435, 'bagging_fraction': 0.5849744075572939, 'bagging_freq': 1, 'lambda_l1': 1.302874941138641, 'lambda_l2': 1.2802964163199118, 'num_boost_round': 301}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:32,500] Trial 12 finished with value: -0.08275825607402022 and parameters: {'learning_rate': 0.04676106850940675, 'num_leaves': 54, 'max_depth': 3, 'min_data_in_leaf': 48, 'feature_fraction': 0.3158480427211192, 'bagging_fraction': 0.5973849750958671, 'bagging_freq': 3, 'lambda_l1': 1.1356950582543934, 'lambda_l2': 1.0888733117933755, 'num_boost_round': 398}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:33,882] Trial 13 finished with value: -0.07138265802334023 and parameters: {'learning_rate': 0.09980918596810297, 'num_leaves': 35, 'max_depth': 3, 'min_data_in_leaf': 75, 'feature_fraction': 0.37529180478007984, 'bagging_fraction': 0.5252715620376821, 'bagging_freq': 1, 'lambda_l1': 3.4498839763590965, 'lambda_l2': 3.7602488704106234, 'num_boost_round': 275}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:35,397] Trial 14 finished with value: -0.07046593311245633 and parameters: {'learning_rate': 0.017251789430967935, 'num_leaves': 17, 'max_depth': 5, 'min_data_in_leaf': 28, 'feature_fraction': 0.28093052515104344, 'bagging_fraction': 0.42559068614070206, 'bagging_freq': 6, 'lambda_l1': 4.846349260243591, 'lambda_l2': 1.074631147113165, 'num_boost_round': 392}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:36,849] Trial 15 finished with value: -0.06616226940666109 and parameters: {'learning_rate': 0.03816566260739273, 'num_leaves': 56, 'max_depth': 4, 'min_data_in_leaf': 54, 'feature_fraction': 0.10189604786123588, 'bagging_fraction': 0.5349787103541079, 'bagging_freq': 3, 'lambda_l1': 0.02692871356053672, 'lambda_l2': 3.8187369745742643, 'num_boost_round': 204}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:38,528] Trial 16 finished with value: -0.0906281670735897 and parameters: {'learning_rate': 0.07321009283185596, 'num_leaves': 45, 'max_depth': 6, 'min_data_in_leaf': 29, 'feature_fraction': 0.44825120046077593, 'bagging_fraction': 0.47802517521534066, 'bagging_freq': 2, 'lambda_l1': 2.136293678114527, 'lambda_l2': 2.180499167861401, 'num_boost_round': 305}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:40,063] Trial 17 finished with value: -0.08949274110588082 and parameters: {'learning_rate': 0.010788310365219508, 'num_leaves': 31, 'max_depth': 3, 'min_data_in_leaf': 82, 'feature_fraction': 0.34659994882697653, 'bagging_fraction': 0.20593694356581443, 'bagging_freq': 2, 'lambda_l1': 0.8523063926605656, 'lambda_l2': 1.7285869917940033, 'num_boost_round': 445}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:41,500] Trial 18 finished with value: -0.08189721279939315 and parameters: {'learning_rate': 0.0230904070701161, 'num_leaves': 45, 'max_depth': 4, 'min_data_in_leaf': 14, 'feature_fraction': 0.2418747376691611, 'bagging_fraction': 0.36408816903572394, 'bagging_freq': 5, 'lambda_l1': 1.7692605644067934, 'lambda_l2': 3.2138272724295565, 'num_boost_round': 369}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:42,941] Trial 19 finished with value: -0.0803752641893542 and parameters: {'learning_rate': 0.05799416629222157, 'num_leaves': 59, 'max_depth': 5, 'min_data_in_leaf': 68, 'feature_fraction': 0.26166750169446507, 'bagging_fraction': 0.45311657874880484, 'bagging_freq': 3, 'lambda_l1': 3.286207831937887, 'lambda_l2': 0.5854117658759617, 'num_boost_round': 258}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:44,344] Trial 20 finished with value: -0.08689953768541206 and parameters: {'learning_rate': 0.03789863413445906, 'num_leaves': 22, 'max_depth': 3, 'min_data_in_leaf': 99, 'feature_fraction': 0.33994387043058, 'bagging_fraction': 0.5590133807173527, 'bagging_freq': 1, 'lambda_l1': 2.814154168201571, 'lambda_l2': 2.4542070533199594, 'num_boost_round': 318}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:46,294] Trial 21 finished with value: -0.10138883715492544 and parameters: {'learning_rate': 0.011663176891173237, 'num_leaves': 64, 'max_depth': 6, 'min_data_in_leaf': 28, 'feature_fraction': 0.1705696870979087, 'bagging_fraction': 0.2912191062416222, 'bagging_freq': 4, 'lambda_l1': 2.2367999218552184, 'lambda_l2': 2.322689930653687, 'num_boost_round': 282}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:48,281] Trial 22 finished with value: -0.06923167295733393 and parameters: {'learning_rate': 0.011466079350794358, 'num_leaves': 55, 'max_depth': 6, 'min_data_in_leaf': 36, 'feature_fraction': 0.10575756811731074, 'bagging_fraction': 0.302570957463143, 'bagging_freq': 5, 'lambda_l1': 2.069931042013509, 'lambda_l2': 4.14379616379793, 'num_boost_round': 237}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:50,164] Trial 23 finished with value: -0.07175598274267703 and parameters: {'learning_rate': 0.022472348221928215, 'num_leaves': 51, 'max_depth': 6, 'min_data_in_leaf': 55, 'feature_fraction': 0.14904745363435254, 'bagging_fraction': 0.22246174376609898, 'bagging_freq': 2, 'lambda_l1': 1.5814583920007674, 'lambda_l2': 2.734972804376943, 'num_boost_round': 273}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:52,412] Trial 24 finished with value: -0.07315032063964748 and parameters: {'learning_rate': 0.011443521305185094, 'num_leaves': 64, 'max_depth': 5, 'min_data_in_leaf': 18, 'feature_fraction': 0.40691034110751656, 'bagging_fraction': 0.372891476183738, 'bagging_freq': 3, 'lambda_l1': 3.764190395703329, 'lambda_l2': 0.666141074478378, 'num_boost_round': 362}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:54,662] Trial 25 finished with value: -0.07033534082972404 and parameters: {'learning_rate': 0.0095162121250616, 'num_leaves': 59, 'max_depth': 6, 'min_data_in_leaf': 21, 'feature_fraction': 0.3444417609535309, 'bagging_fraction': 0.5180600873082568, 'bagging_freq': 2, 'lambda_l1': 3.006546565606238, 'lambda_l2': 1.6780892728694936, 'num_boost_round': 223}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:56,882] Trial 26 finished with value: -0.10673231714505117 and parameters: {'learning_rate': 0.019213728770734496, 'num_leaves': 40, 'max_depth': 5, 'min_data_in_leaf': 38, 'feature_fraction': 0.2586127737755961, 'bagging_fraction': 0.32306740890682845, 'bagging_freq': 4, 'lambda_l1': 0.887570362361239, 'lambda_l2': 3.56657631037611, 'num_boost_round': 255}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:49:58,673] Trial 27 finished with value: -0.08924409181391363 and parameters: {'learning_rate': 0.027469123191163757, 'num_leaves': 42, 'max_depth': 5, 'min_data_in_leaf': 51, 'feature_fraction': 0.2510571470753267, 'bagging_fraction': 0.32635643393199526, 'bagging_freq': 7, 'lambda_l1': 0.763378510756177, 'lambda_l2': 3.7749204593753953, 'num_boost_round': 257}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:00,204] Trial 28 finished with value: -0.09339852511840155 and parameters: {'learning_rate': 0.019282309476059554, 'num_leaves': 35, 'max_depth': 5, 'min_data_in_leaf': 42, 'feature_fraction': 0.31345303544398373, 'bagging_fraction': 0.4978074625755003, 'bagging_freq': 3, 'lambda_l1': 1.1780908883208745, 'lambda_l2': 3.466728679903258, 'num_boost_round': 214}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:01,792] Trial 29 finished with value: -0.08178563167094158 and parameters: {'learning_rate': 0.03997020054255503, 'num_leaves': 30, 'max_depth': 4, 'min_data_in_leaf': 62, 'feature_fraction': 0.2755112940722727, 'bagging_fraction': 0.24517443231777797, 'bagging_freq': 1, 'lambda_l1': 0.016881111378465263, 'lambda_l2': 2.8648818448969773, 'num_boost_round': 245}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:03,310] Trial 30 finished with value: -0.0934560383537398 and parameters: {'learning_rate': 0.08154366958417072, 'num_leaves': 20, 'max_depth': 4, 'min_data_in_leaf': 46, 'feature_fraction': 0.37301274525990447, 'bagging_fraction': 0.5539466513200291, 'bagging_freq': 5, 'lambda_l1': 0.8247825616808057, 'lambda_l2': 4.908278278754027, 'num_boost_round': 320}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:05,024] Trial 31 finished with value: -0.07209566361429878 and parameters: {'learning_rate': 0.013760774058713055, 'num_leaves': 50, 'max_depth': 6, 'min_data_in_leaf': 36, 'feature_fraction': 0.17949088866888296, 'bagging_fraction': 0.2800203147187977, 'bagging_freq': 4, 'lambda_l1': 2.3495957045857616, 'lambda_l2': 3.142970976044916, 'num_boost_round': 283}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:07,553] Trial 32 finished with value: -0.08818109819206467 and parameters: {'learning_rate': 0.01399838602810768, 'num_leaves': 61, 'max_depth': 6, 'min_data_in_leaf': 34, 'feature_fraction': 0.1361964101824226, 'bagging_fraction': 0.3295663752992116, 'bagging_freq': 4, 'lambda_l1': 1.8855453015298687, 'lambda_l2': 2.2980145236795697, 'num_boost_round': 295}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:10,619] Trial 33 finished with value: -0.10023997250705684 and parameters: {'learning_rate': 0.007568835734556018, 'num_leaves': 61, 'max_depth': 5, 'min_data_in_leaf': 27, 'feature_fraction': 0.2358509906553767, 'bagging_fraction': 0.29300456123415464, 'bagging_freq': 1, 'lambda_l1': 1.4043280000611267, 'lambda_l2': 4.2513136434340115, 'num_boost_round': 268}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:15,769] Trial 34 finished with value: -0.07048375490755082 and parameters: {'learning_rate': 0.005064357443636819, 'num_leaves': 26, 'max_depth': 6, 'min_data_in_leaf': 23, 'feature_fraction': 0.16893975275517445, 'bagging_fraction': 0.25587482187424593, 'bagging_freq': 4, 'lambda_l1': 0.42349389080126165, 'lambda_l2': 3.4533905343456275, 'num_boost_round': 319}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:18,585] Trial 35 finished with value: -0.068500933359079 and parameters: {'learning_rate': 0.020887488777371576, 'num_leaves': 42, 'max_depth': 6, 'min_data_in_leaf': 33, 'feature_fraction': 0.18702011017779602, 'bagging_fraction': 0.36111448204952723, 'bagging_freq': 2, 'lambda_l1': 2.5719470883001327, 'lambda_l2': 2.6538355519048475, 'num_boost_round': 249}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:21,200] Trial 36 finished with value: -0.08460034694205942 and parameters: {'learning_rate': 0.008759274217668997, 'num_leaves': 53, 'max_depth': 2, 'min_data_in_leaf': 10, 'feature_fraction': 0.20340932270324208, 'bagging_fraction': 0.44965815894305, 'bagging_freq': 4, 'lambda_l1': 2.38293261327412, 'lambda_l2': 3.030190297241217, 'num_boost_round': 288}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:23,715] Trial 37 finished with value: -0.06109139604835901 and parameters: {'learning_rate': 0.025387376575329103, 'num_leaves': 47, 'max_depth': 5, 'min_data_in_leaf': 40, 'feature_fraction': 0.32904822822210594, 'bagging_fraction': 0.31114857321574063, 'bagging_freq': 6, 'lambda_l1': 2.831572807524864, 'lambda_l2': 1.9189731186817087, 'num_boost_round': 222}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:25,849] Trial 38 finished with value: -0.06465870966601603 and parameters: {'learning_rate': 0.03180306005531444, 'num_leaves': 57, 'max_depth': 6, 'min_data_in_leaf': 87, 'feature_fraction': 0.28979640818087404, 'bagging_fraction': 0.39029602966497295, 'bagging_freq': 3, 'lambda_l1': 0.9902581614723105, 'lambda_l2': 1.5200769189156405, 'num_boost_round': 344}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:28,460] Trial 39 finished with value: -0.06871987473933533 and parameters: {'learning_rate': 0.017649578604836322, 'num_leaves': 39, 'max_depth': 5, 'min_data_in_leaf': 57, 'feature_fraction': 0.21419993881049576, 'bagging_fraction': 0.42497915946159937, 'bagging_freq': 10, 'lambda_l1': 0.6520712445668975, 'lambda_l2': 2.0292650473523213, 'num_boost_round': 447}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:31,178] Trial 40 finished with value: -0.07660834652123982 and parameters: {'learning_rate': 0.01445009452819714, 'num_leaves': 33, 'max_depth': 2, 'min_data_in_leaf': 44, 'feature_fraction': 0.4530917087977354, 'bagging_fraction': 0.3496378637541886, 'bagging_freq': 7, 'lambda_l1': 4.387751281721941, 'lambda_l2': 0.04751341772695722, 'num_boost_round': 259}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:37,849] Trial 41 finished with value: -0.08698484305655242 and parameters: {'learning_rate': 0.006242247652901255, 'num_leaves': 63, 'max_depth': 5, 'min_data_in_leaf': 27, 'feature_fraction': 0.23162046247055412, 'bagging_fraction': 0.2957918225173426, 'bagging_freq': 1, 'lambda_l1': 1.4862852614434705, 'lambda_l2': 4.265605122644585, 'num_boost_round': 270}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:41,827] Trial 42 finished with value: -0.09663855273521417 and parameters: {'learning_rate': 0.00800407582657189, 'num_leaves': 61, 'max_depth': 5, 'min_data_in_leaf': 23, 'feature_fraction': 0.26087424707315865, 'bagging_fraction': 0.2869725606118402, 'bagging_freq': 1, 'lambda_l1': 1.4038841580214774, 'lambda_l2': 4.080077220774447, 'num_boost_round': 239}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:45,410] Trial 43 finished with value: -0.08976961868602046 and parameters: {'learning_rate': 0.006392171941014888, 'num_leaves': 59, 'max_depth': 4, 'min_data_in_leaf': 31, 'feature_fraction': 0.20002215245978916, 'bagging_fraction': 0.26646070849235065, 'bagging_freq': 2, 'lambda_l1': 1.12460077682718, 'lambda_l2': 4.484713861661389, 'num_boost_round': 271}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:48,195] Trial 44 finished with value: -0.08663587147644972 and parameters: {'learning_rate': 0.010143684607783842, 'num_leaves': 64, 'max_depth': 6, 'min_data_in_leaf': 25, 'feature_fraction': 0.23472086637334644, 'bagging_fraction': 0.24618246367032248, 'bagging_freq': 1, 'lambda_l1': 1.8272599836446248, 'lambda_l2': 3.5796489268789613, 'num_boost_round': 302}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:51,270] Trial 45 finished with value: -0.0616402862574988 and parameters: {'learning_rate': 0.005866527027506232, 'num_leaves': 52, 'max_depth': 5, 'min_data_in_leaf': 37, 'feature_fraction': 0.29966164893344027, 'bagging_fraction': 0.5770991093811748, 'bagging_freq': 2, 'lambda_l1': 0.22320741528942278, 'lambda_l2': 3.9716329922248397, 'num_boost_round': 227}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:54,495] Trial 46 finished with value: -0.08728580827350811 and parameters: {'learning_rate': 0.007753019977472893, 'num_leaves': 27, 'max_depth': 6, 'min_data_in_leaf': 48, 'feature_fraction': 0.12862962315727633, 'bagging_fraction': 0.3401417484034252, 'bagging_freq': 3, 'lambda_l1': 0.5538981222210524, 'lambda_l2': 4.564048218913952, 'num_boost_round': 212}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:56,431] Trial 47 finished with value: -0.08227803218880522 and parameters: {'learning_rate': 0.013235794590914457, 'num_leaves': 48, 'max_depth': 4, 'min_data_in_leaf': 92, 'feature_fraction': 0.27601568523651643, 'bagging_fraction': 0.5416618472120682, 'bagging_freq': 1, 'lambda_l1': 2.0521829387978463, 'lambda_l2': 3.3206291929278873, 'num_boost_round': 329}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:57,963] Trial 48 finished with value: -0.08281602386438748 and parameters: {'learning_rate': 0.05143409023116193, 'num_leaves': 57, 'max_depth': 3, 'min_data_in_leaf': 39, 'feature_fraction': 0.3574381135921755, 'bagging_fraction': 0.3129546637248605, 'bagging_freq': 5, 'lambda_l1': 1.300231034111941, 'lambda_l2': 2.9323856650787503, 'num_boost_round': 287}. Best is trial 2 with value: -0.10733999709173266.
# [I 2025-08-19 14:50:59,678] Trial 49 finished with value: -0.09085991355826749 and parameters: {'learning_rate': 0.03142329176385994, 'num_leaves': 61, 'max_depth': 3, 'min_data_in_leaf': 31, 'feature_fraction': 0.32288530752682454, 'bagging_fraction': 0.5009025593333467, 'bagging_freq': 2, 'lambda_l1': 1.7203699811694773, 'lambda_l2': 0.8366676492413123, 'num_boost_round': 265}. Best is trial 2 with value: -0.10733999709173266.
# Training on feature set 1/12, model 3/5
# [I 2025-08-19 14:51:01,264] A new study created in memory with name: no-name-e1dab572-8944-4fcc-bc7e-d4366ed66f14
# [I 2025-08-19 14:51:03,183] Trial 0 finished with value: -0.07490628080181352 and parameters: {'learning_rate': 0.015355286838886862, 'num_leaves': 62, 'max_depth': 5, 'min_data_in_leaf': 64, 'feature_fraction': 0.1624074561769746, 'bagging_fraction': 0.26239780813448105, 'bagging_freq': 1, 'lambda_l1': 4.330880728874676, 'lambda_l2': 3.005575058716044, 'num_boost_round': 413}. Best is trial 0 with value: -0.07490628080181352.
# [I 2025-08-19 14:51:05,442] Trial 1 finished with value: -0.11277886291191724 and parameters: {'learning_rate': 0.005318033256270142, 'num_leaves': 63, 'max_depth': 6, 'min_data_in_leaf': 29, 'feature_fraction': 0.17272998688284025, 'bagging_fraction': 0.27336180394137355, 'bagging_freq': 4, 'lambda_l1': 2.6237821581611893, 'lambda_l2': 2.1597250932105787, 'num_boost_round': 287}. Best is trial 1 with value: -0.11277886291191724.
# [I 2025-08-19 14:51:07,004] Trial 2 finished with value: -0.10220368483355244 and parameters: {'learning_rate': 0.03126143958203108, 'num_leaves': 22, 'max_depth': 3, 'min_data_in_leaf': 43, 'feature_fraction': 0.28242799368681437, 'bagging_fraction': 0.5140703845572054, 'bagging_freq': 2, 'lambda_l1': 2.571172192068058, 'lambda_l2': 2.9620728443102124, 'num_boost_round': 213}. Best is trial 1 with value: -0.11277886291191724.
# [I 2025-08-19 14:51:08,591] Trial 3 finished with value: -0.07966293818946438 and parameters: {'learning_rate': 0.030860579740535368, 'num_leaves': 24, 'max_depth': 2, 'min_data_in_leaf': 96, 'feature_fraction': 0.4862528132298237, 'bagging_fraction': 0.5233589392465845, 'bagging_freq': 4, 'lambda_l1': 0.48836057003191935, 'lambda_l2': 3.4211651325607844, 'num_boost_round': 332}. Best is trial 1 with value: -0.11277886291191724.
# [I 2025-08-19 14:51:10,450] Trial 4 finished with value: -0.07217390978452554 and parameters: {'learning_rate': 0.007206848764305203, 'num_leaves': 40, 'max_depth': 2, 'min_data_in_leaf': 92, 'feature_fraction': 0.20351199264000677, 'bagging_fraction': 0.46500891374159276, 'bagging_freq': 4, 'lambda_l1': 2.600340105889054, 'lambda_l2': 2.7335513967163982, 'num_boost_round': 255}. Best is trial 1 with value: -0.11277886291191724.
# [I 2025-08-19 14:51:12,802] Trial 5 finished with value: -0.1045254716397191 and parameters: {'learning_rate': 0.09129115219600122, 'num_leaves': 53, 'max_depth': 6, 'min_data_in_leaf': 91, 'feature_fraction': 0.3391599915244341, 'bagging_fraction': 0.5687496940092467, 'bagging_freq': 1, 'lambda_l1': 0.979914312095726, 'lambda_l2': 0.22613644455269033, 'num_boost_round': 297}. Best is trial 1 with value: -0.11277886291191724.
# [I 2025-08-19 14:51:16,267] Trial 6 finished with value: -0.0997176619529363 and parameters: {'learning_rate': 0.016019568611465234, 'num_leaves': 29, 'max_depth': 6, 'min_data_in_leaf': 42, 'feature_fraction': 0.2123738038749523, 'bagging_fraction': 0.4170784332632994, 'bagging_freq': 2, 'lambda_l1': 4.010984903770199, 'lambda_l2': 0.3727532183988541, 'num_boost_round': 497}. Best is trial 1 with value: -0.11277886291191724.
# [I 2025-08-19 14:51:18,187] Trial 7 finished with value: -0.08133976053049105 and parameters: {'learning_rate': 0.05054562991054155, 'num_leaves': 25, 'max_depth': 2, 'min_data_in_leaf': 84, 'feature_fraction': 0.38274293753904687, 'bagging_fraction': 0.4916028672163949, 'bagging_freq': 8, 'lambda_l1': 0.3702232586704518, 'lambda_l2': 1.7923286427213632, 'num_boost_round': 234}. Best is trial 1 with value: -0.11277886291191724.
# [I 2025-08-19 14:51:19,612] Trial 8 finished with value: -0.07277953859788107 and parameters: {'learning_rate': 0.06635802485202448, 'num_leaves': 46, 'max_depth': 3, 'min_data_in_leaf': 15, 'feature_fraction': 0.2243929286862649, 'bagging_fraction': 0.33007332881069884, 'bagging_freq': 8, 'lambda_l1': 3.1877873567760657, 'lambda_l2': 4.436063712881633, 'num_boost_round': 342}. Best is trial 1 with value: -0.11277886291191724.
# ...
# [I 2025-08-19 15:00:12,096] Trial 23 finished with value: -0.05165258142310908 and parameters: {'learning_rate': 0.024938454799599545, 'num_leaves': 51, 'max_depth': 4, 'min_data_in_leaf': 56, 'feature_fraction': 0.4933915411042225, 'bagging_fraction': 0.594120380250916, 'bagging_freq': 5, 'lambda_l1': 1.1224225326867372, 'lambda_l2': 1.5053542166722005, 'num_boost_round': 361}. Best is trial 12 with value: -0.07833133234530087.
# [I 2025-08-19 15:00:13,775] Trial 24 finished with value: -0.06915742904865295 and parameters: {'learning_rate': 0.007161260690451953, 'num_leaves': 44, 'max_depth': 5, 'min_data_in_leaf': 34, 'feature_fraction': 0.43998980108300073, 'bagging_fraction': 0.39789930091965114, 'bagging_freq': 9, 'lambda_l1': 1.98997164137562, 'lambda_l2': 0.666141074478378, 'num_boost_round': 317}. Best is trial 12 with value: -0.07833133234530087.
# [I 2025-08-19 15:00:14,874] Trial 25 finished with value: -0.06688075379118448 and parameters: {'learning_rate': 0.041880205897578945, 'num_leaves': 54, 'max_depth': 4, 'min_data_in_leaf': 49, 'feature_fraction': 0.3733872027780101, 'bagging_fraction': 0.5446273716632684, 'bagging_freq': 9, 'lambda_l1': 1.8607765228464792, 'lambda_l2': 1.9731134169095874, 'num_boost_round': 366}. Best is trial 12 with value: -0.07833133234530087.
# [I 2025-08-19 15:00:16,148] Trial 26 finished with value: -0.06138051883535689 and parameters: {'learning_rate': 0.01806602570670552, 'num_leaves': 49, 'max_depth': 3, 'min_data_in_leaf': 70, 'feature_fraction': 0.46708931537933784, 'bagging_fraction': 0.44927163098711337, 'bagging_freq': 6, 'lambda_l1': 1.0935582809793845, 'lambda_l2': 2.4981686629085877, 'num_boost_round': 436}. Best is trial 12 with value: -0.07833133234530087.
# [I 2025-08-19 15:00:17,397] Trial 27 finished with value: -0.07446348738488485 and parameters: {'learning_rate': 0.01213163856601102, 'num_leaves': 60, 'max_depth': 5, 'min_data_in_leaf': 84, 'feature_fraction': 0.42060552684090596, 'bagging_fraction': 0.3719268671409409, 'bagging_freq': 3, 'lambda_l1': 2.912493416550591, 'lambda_l2': 1.3843673756392965, 'num_boost_round': 388}. Best is trial 12 with value: -0.07833133234530087.
# [I 2025-08-19 15:00:18,542] Trial 28 finished with value: -0.06665377534826926 and parameters: {'learning_rate': 0.009322445097269967, 'num_leaves': 32, 'max_depth': 4, 'min_data_in_leaf': 19, 'feature_fraction': 0.33544749277117525, 'bagging_fraction': 0.3262147719691429, 'bagging_freq': 7, 'lambda_l1': 0.7119822321677511, 'lambda_l2': 2.452705303719728, 'num_boost_round': 429}. Best is trial 12 with value: -0.07833133234530087.
# [I 2025-08-19 15:00:19,848] Trial 29 finished with value: -0.06341610879776538 and parameters: {'learning_rate': 0.017115849701535964, 'num_leaves': 61, 'max_depth': 5, 'min_data_in_leaf': 62, 'feature_fraction': 0.4698124449705517, 'bagging_fraction': 0.22722533107651968, 'bagging_freq': 5, 'lambda_l1': 2.272845144522077, 'lambda_l2': 0.6115771361104549, 'num_boost_round': 418}. Best is trial 12 with value: -0.07833133234530087.
# [I 2025-08-19 15:00:21,155] Trial 30 finished with value: -0.07391504983121158 and parameters: {'learning_rate': 0.013696554688785278, 'num_leaves': 43, 'max_depth': 6, 'min_data_in_leaf': 100, 'feature_fraction': 0.26748410189916894, 'bagging_fraction': 0.48536554866763226, 'bagging_freq': 8, 'lambda_l1': 3.90846172275877, 'lambda_l2': 3.330396760937711, 'num_boost_round': 474}. Best is trial 12 with value: -0.07833133234530087.
# [I 2025-08-19 15:00:22,297] Trial 31 finished with value: -0.06141705679170585 and parameters: {'learning_rate': 0.0122284667168839, 'num_leaves': 59, 'max_depth': 5, 'min_data_in_leaf': 87, 'feature_fraction': 0.42511213204333076, 'bagging_fraction': 0.3705021669560832, 'bagging_freq': 3, 'lambda_l1': 2.856452579166266, 'lambda_l2': 1.3413864889847391, 'num_boost_round': 388}. Best is trial 12 with value: -0.07833133234530087.
# [I 2025-08-19 15:00:23,750] Trial 32 finished with value: -0.07461214741774287 and parameters: {'learning_rate': 0.006682512409228346, 'num_leaves': 64, 'max_depth': 6, 'min_data_in_leaf': 80, 'feature_fraction': 0.39056876062815393, 'bagging_fraction': 0.3897663214837966, 'bagging_freq': 3, 'lambda_l1': 3.0309655425212836, 'lambda_l2': 1.8109982274577838, 'num_boost_round': 360}. Best is trial 12 with value: -0.07833133234530087.
# [I 2025-08-19 15:00:25,168] Trial 33 finished with value: -0.06311948962184044 and parameters: {'learning_rate': 0.005856082059369341, 'num_leaves': 63, 'max_depth': 6, 'min_data_in_leaf': 72, 'feature_fraction': 0.3858595229591875, 'bagging_fraction': 0.2976459146371758, 'bagging_freq': 3, 'lambda_l1': 1.7926058327013146, 'lambda_l2': 2.081962715461346, 'num_boost_round': 355}. Best is trial 12 with value: -0.07833133234530087.
# [I 2025-08-19 15:00:26,495] Trial 34 finished with value: -0.0759876725041051 and parameters: {'learning_rate': 0.007063803525924195, 'num_leaves': 64, 'max_depth': 6, 'min_data_in_leaf': 79, 'feature_fraction': 0.3567420000643255, 'bagging_fraction': 0.3950349285515456, 'bagging_freq': 4, 'lambda_l1': 3.555158948285918, 'lambda_l2': 1.820872586880459, 'num_boost_round': 319}. Best is trial 12 with value: -0.07833133234530087.
# [I 2025-08-19 15:00:27,957] Trial 35 finished with value: -0.07387381267785303 and parameters: {'learning_rate': 0.008816703280951226, 'num_leaves': 54, 'max_depth': 6, 'min_data_in_leaf': 63, 'feature_fraction': 0.3530377129473418, 'bagging_fraction': 0.4195989104439435, 'bagging_freq': 4, 'lambda_l1': 3.6220128962068774, 'lambda_l2': 2.8512480340852093, 'num_boost_round': 315}. Best is trial 12 with value: -0.07833133234530087.
# [I 2025-08-19 15:00:29,767] Trial 36 finished with value: -0.0646033081209396 and parameters: {'learning_rate': 0.005007228552389967, 'num_leaves': 64, 'max_depth': 5, 'min_data_in_leaf': 90, 'feature_fraction': 0.3127854496355623, 'bagging_fraction': 0.5043943440443224, 'bagging_freq': 5, 'lambda_l1': 2.399977470169059, 'lambda_l2': 1.8393440052527548, 'num_boost_round': 282}. Best is trial 12 with value: -0.07833133234530087.
# [I 2025-08-19 15:00:31,337] Trial 37 finished with value: -0.08025297090808564 and parameters: {'learning_rate': 0.008404801164495445, 'num_leaves': 56, 'max_depth': 6, 'min_data_in_leaf': 38, 'feature_fraction': 0.4996476481100353, 'bagging_fraction': 0.45189225913973674, 'bagging_freq': 4, 'lambda_l1': 4.78875825056611, 'lambda_l2': 2.2979416456614157, 'num_boost_round': 323}. Best is trial 37 with value: -0.08025297090808564.
# [I 2025-08-19 15:00:32,870] Trial 38 finished with value: -0.06478810497011014 and parameters: {'learning_rate': 0.00804862739439611, 'num_leaves': 20, 'max_depth': 6, 'min_data_in_leaf': 21, 'feature_fraction': 0.26678657256765825, 'bagging_fraction': 0.3469598689894038, 'bagging_freq': 4, 'lambda_l1': 4.657619442924953, 'lambda_l2': 3.2965867300655693, 'num_boost_round': 271}. Best is trial 37 with value: -0.08025297090808564.
# [I 2025-08-19 15:00:34,413] Trial 39 finished with value: -0.06698369342014383 and parameters: {'learning_rate': 0.00605740692911471, 'num_leaves': 48, 'max_depth': 3, 'min_data_in_leaf': 37, 'feature_fraction': 0.4705763063643051, 'bagging_fraction': 0.4457390868917041, 'bagging_freq': 2, 'lambda_l1': 4.262870175969847, 'lambda_l2': 2.464817766117824, 'num_boost_round': 327}. Best is trial 37 with value: -0.08025297090808564.
# [I 2025-08-19 15:00:36,201] Trial 40 finished with value: -0.06964888161194326 and parameters: {'learning_rate': 0.010233152521383062, 'num_leaves': 52, 'max_depth': 6, 'min_data_in_leaf': 96, 'feature_fraction': 0.4812425259307275, 'bagging_fraction': 0.5251675889273628, 'bagging_freq': 4, 'lambda_l1': 4.4418268348029315, 'lambda_l2': 1.2348730220594761, 'num_boost_round': 305}. Best is trial 37 with value: -0.08025297090808564.
# [I 2025-08-19 15:00:38,170] Trial 41 finished with value: -0.06349168720802018 and parameters: {'learning_rate': 0.0064995983784328, 'num_leaves': 56, 'max_depth': 6, 'min_data_in_leaf': 39, 'feature_fraction': 0.4392567010505483, 'bagging_fraction': 0.46967296965375754, 'bagging_freq': 6, 'lambda_l1': 4.967411011074679, 'lambda_l2': 2.258990426768597, 'num_boost_round': 332}. Best is trial 37 with value: -0.08025297090808564.
# [I 2025-08-19 15:00:40,312] Trial 42 finished with value: -0.06500448586516472 and parameters: {'learning_rate': 0.007848663661074262, 'num_leaves': 60, 'max_depth': 6, 'min_data_in_leaf': 48, 'feature_fraction': 0.44686880136138746, 'bagging_fraction': 0.4108105693937592, 'bagging_freq': 4, 'lambda_l1': 2.6337161911624545, 'lambda_l2': 1.7517783901790962, 'num_boost_round': 336}. Best is trial 37 with value: -0.08025297090808564.
# [I 2025-08-19 15:00:41,606] Trial 43 finished with value: -0.07264543767075388 and parameters: {'learning_rate': 0.02647712436956317, 'num_leaves': 62, 'max_depth': 4, 'min_data_in_leaf': 58, 'feature_fraction': 0.49925115258295527, 'bagging_fraction': 0.4632723193982994, 'bagging_freq': 5, 'lambda_l1': 3.7151890823122837, 'lambda_l2': 2.6864930996305914, 'num_boost_round': 300}. Best is trial 37 with value: -0.08025297090808564.
# [I 2025-08-19 15:00:42,823] Trial 44 finished with value: -0.05628656919371994 and parameters: {'learning_rate': 0.06116527464839997, 'num_leaves': 28, 'max_depth': 5, 'min_data_in_leaf': 30, 'feature_fraction': 0.4066542582850263, 'bagging_fraction': 0.43757489497780205, 'bagging_freq': 1, 'lambda_l1': 1.1753409965691548, 'lambda_l2': 3.0670566112817053, 'num_boost_round': 350}. Best is trial 37 with value: -0.08025297090808564.
# [I 2025-08-19 15:00:44,382] Trial 45 finished with value: -0.05818811781882206 and parameters: {'learning_rate': 0.0102695162290865, 'num_leaves': 41, 'max_depth': 4, 'min_data_in_leaf': 52, 'feature_fraction': 0.36221871181982257, 'bagging_fraction': 0.40515574853285213, 'bagging_freq': 6, 'lambda_l1': 0.42148921747696244, 'lambda_l2': 0.8888393558997215, 'num_boost_round': 398}. Best is trial 37 with value: -0.08025297090808564.
# [I 2025-08-19 15:00:47,114] Trial 46 finished with value: -0.08680371055869063 and parameters: {'learning_rate': 0.007945849584902081, 'num_leaves': 56, 'max_depth': 6, 'min_data_in_leaf': 66, 'feature_fraction': 0.4786387189777277, 'bagging_fraction': 0.3886926084368408, 'bagging_freq': 4, 'lambda_l1': 1.7161114055752686, 'lambda_l2': 1.6775490685438608, 'num_boost_round': 374}. Best is trial 46 with value: -0.08680371055869063.
# [I 2025-08-19 15:00:48,917] Trial 47 finished with value: -0.054017122813421525 and parameters: {'learning_rate': 0.007240350811559021, 'num_leaves': 54, 'max_depth': 2, 'min_data_in_leaf': 73, 'feature_fraction': 0.47997900847558556, 'bagging_fraction': 0.3837369314283482, 'bagging_freq': 2, 'lambda_l1': 1.7126267209919896, 'lambda_l2': 0.43915424644029355, 'num_boost_round': 254}. Best is trial 46 with value: -0.08680371055869063.
# [I 2025-08-19 15:00:51,181] Trial 48 finished with value: -0.07892428150619132 and parameters: {'learning_rate': 0.00609532049025203, 'num_leaves': 35, 'max_depth': 6, 'min_data_in_leaf': 65, 'feature_fraction': 0.32626310592206365, 'bagging_fraction': 0.34512094575435304, 'bagging_freq': 3, 'lambda_l1': 2.690286273122342, 'lambda_l2': 2.026542612112564, 'num_boost_round': 422}. Best is trial 46 with value: -0.08680371055869063.
# [I 2025-08-19 15:00:53,335] Trial 49 finished with value: -0.033318610560383766 and parameters: {'learning_rate': 0.0059901012532092126, 'num_leaves': 34, 'max_depth': 6, 'min_data_in_leaf': 67, 'feature_fraction': 0.17800398167489329, 'bagging_fraction': 0.30322859249584033, 'bagging_freq': 2, 'lambda_l1': 2.622360217327315, 'lambda_l2': 2.2981499220159773, 'num_boost_round': 423}. Best is trial 46 with value: -0.08680371055869063.
# [I 2025-08-19 15:00:54,920] A new study created in memory with name: no-name-0175805c-48d6-4cae-ba6d-0a9b2fe0ae4f
# Training on feature set 3/12, model 2/5
# [I 2025-08-19 15:00:55,977] Trial 0 finished with value: -0.06218539508214488 and parameters: {'learning_rate': 0.015355286838886862, 'num_leaves': 62, 'max_depth': 5, 'min_data_in_leaf': 64, 'feature_fraction': 0.1624074561769746, 'bagging_fraction': 0.26239780813448105, 'bagging_freq': 1, 'lambda_l1': 4.330880728874676, 'lambda_l2': 3.005575058716044, 'num_boost_round': 413}. Best is trial 0 with value: -0.06218539508214488.
# [I 2025-08-19 15:00:57,324] Trial 1 finished with value: -0.06512459586665434 and parameters: {'learning_rate': 0.005318033256270142, 'num_leaves': 63, 'max_depth': 6, 'min_data_in_leaf': 29, 'feature_fraction': 0.17272998688284025, 'bagging_fraction': 0.27336180394137355, 'bagging_freq': 4, 'lambda_l1': 2.6237821581611893, 'lambda_l2': 2.1597250932105787, 'num_boost_round': 287}. Best is trial 1 with value: -0.06512459586665434.
# [I 2025-08-19 15:00:58,567] Trial 2 finished with value: -0.0783350357366696 and parameters: {'learning_rate': 0.03126143958203108, 'num_leaves': 22, 'max_depth': 3, 'min_data_in_leaf': 43, 'feature_fraction': 0.28242799368681437, 'bagging_fraction': 0.5140703845572054, 'bagging_freq': 2, 'lambda_l1': 2.571172192068058, 'lambda_l2': 2.9620728443102124, 'num_boost_round': 213}. Best is trial 2 with value: -0.0783350357366696.
# [I 2025-08-19 15:00:59,520] Trial 3 finished with value: -0.06518282595281301 and parameters: {'learning_rate': 0.030860579740535368, 'num_leaves': 24, 'max_depth': 2, 'min_data_in_leaf': 96, 'feature_fraction': 0.4862528132298237, 'bagging_fraction': 0.5233589392465845, 'bagging_freq': 4, 'lambda_l1': 0.48836057003191935, 'lambda_l2': 3.4211651325607844, 'num_boost_round': 332}. Best is trial 2 with value: -0.0783350357366696.
# [I 2025-08-19 15:01:00,558] Trial 4 finished with value: -0.062199524083312405 and parameters: {'learning_rate': 0.007206848764305203, 'num_leaves': 40, 'max_depth': 2, 'min_data_in_leaf': 92, 'feature_fraction': 0.20351199264000677, 'bagging_fraction': 0.46500891374159276, 'bagging_freq': 4, 'lambda_l1': 2.600340105889054, 'lambda_l2': 2.7335513967163982, 'num_boost_round': 255}. Best is trial 2 with value: -0.0783350357366696.
# [I 2025-08-19 15:01:01,642] Trial 5 finished with value: -0.07690966838189707 and parameters: {'learning_rate': 0.09129115219600122, 'num_leaves': 53, 'max_depth': 6, 'min_data_in_leaf': 91, 'feature_fraction': 0.3391599915244341, 'bagging_fraction': 0.5687496940092467, 'bagging_freq': 1, 'lambda_l1': 0.979914312095726, 'lambda_l2': 0.22613644455269033, 'num_boost_round': 297}. Best is trial 2 with value: -0.0783350357366696.
# [I 2025-08-19 15:01:02,828] Trial 6 finished with value: -0.0474976418198934 and parameters: {'learning_rate': 0.016019568611465234, 'num_leaves': 29, 'max_depth': 6, 'min_data_in_leaf': 42, 'feature_fraction': 0.2123738038749523, 'bagging_fraction': 0.4170784332632994, 'bagging_freq': 2, 'lambda_l1': 4.010984903770199, 'lambda_l2': 0.3727532183988541, 'num_boost_round': 497}. Best is trial 2 with value: -0.0783350357366696.
# [I 2025-08-19 15:01:03,760] Trial 7 finished with value: -0.0633834713484034 and parameters: {'learning_rate': 0.05054562991054155, 'num_leaves': 25, 'max_depth': 2, 'min_data_in_leaf': 84, 'feature_fraction': 0.38274293753904687, 'bagging_fraction': 0.4916028672163949, 'bagging_freq': 8, 'lambda_l1': 0.3702232586704518, 'lambda_l2': 1.7923286427213632, 'num_boost_round': 234}. Best is trial 2 with value: -0.0783350357366696.
# [I 2025-08-19 15:01:04,747] Trial 8 finished with value: -0.07022006907186201 and parameters: {'learning_rate': 0.06635802485202448, 'num_leaves': 46, 'max_depth': 3, 'min_data_in_leaf': 15, 'feature_fraction': 0.2243929286862649, 'bagging_fraction': 0.33007332881069884, 'bagging_freq': 8, 'lambda_l1': 3.1877873567760657, 'lambda_l2': 4.436063712881633, 'num_boost_round': 342}. Best is trial 2 with value: -0.0783350357366696.

# %%
# further fine-tuning the ridge regression regularization parameter
ensemble.fit_ridge(X_train, y_train, X_val, y_val, range(2000, 15000, 5000))

# %%
ensemble.refit_full(df_train.drop(columns='label'), df_train['label'])

y_test_pred = ensemble.predict(df_test)
y_test_pred_pd = pd.Series(y_test_pred, name = 'prediction')
y_test_pred_pd.index = df_test.index
y_test_pred_pd.to_csv('../data/output/submission6.csv')
# Out:
# Refitting model 1/60 on full data...
# Refitting model 2/60 on full data...
# Refitting model 3/60 on full data...
# Refitting model 4/60 on full data...
# Refitting model 5/60 on full data...
# Refitting model 6/60 on full data...
# Refitting model 7/60 on full data...
# Refitting model 8/60 on full data...
# Refitting model 9/60 on full data...
# Refitting model 10/60 on full data...
# Refitting model 11/60 on full data...
# Refitting model 12/60 on full data...
# Refitting model 13/60 on full data...
# Refitting model 14/60 on full data...
# Refitting model 15/60 on full data...
# Refitting model 16/60 on full data...
# Refitting model 17/60 on full data...
# Refitting model 18/60 on full data...
# Refitting model 19/60 on full data...
# Refitting model 20/60 on full data...
# Refitting model 21/60 on full data...
# Refitting model 22/60 on full data...
# Refitting model 23/60 on full data...
# Refitting model 24/60 on full data...
# Refitting model 25/60 on full data...
# Refitting model 26/60 on full data...
# Refitting model 27/60 on full data...
# Refitting model 28/60 on full data...
# Refitting model 29/60 on full data...
# Refitting model 30/60 on full data...
# Refitting model 31/60 on full data...
# Refitting model 32/60 on full data...
# Refitting model 33/60 on full data...
# Refitting model 34/60 on full data...
# Refitting model 35/60 on full data...
# Refitting model 36/60 on full data...
# Refitting model 37/60 on full data...
# Refitting model 38/60 on full data...
# Refitting model 39/60 on full data...
# Refitting model 40/60 on full data...
# Refitting model 41/60 on full data...
# Refitting model 42/60 on full data...
# Refitting model 43/60 on full data...
# Refitting model 44/60 on full data...
# Refitting model 45/60 on full data...
# Refitting model 46/60 on full data...
# Refitting model 47/60 on full data...
# Refitting model 48/60 on full data...
# Refitting model 49/60 on full data...
# Refitting model 50/60 on full data...
# Refitting model 51/60 on full data...
# Refitting model 52/60 on full data...
# Refitting model 53/60 on full data...
# Refitting model 54/60 on full data...
# Refitting model 55/60 on full data...
# Refitting model 56/60 on full data...
# Refitting model 57/60 on full data...
# Refitting model 58/60 on full data...
# Refitting model 59/60 on full data...
# Refitting model 60/60 on full data...
