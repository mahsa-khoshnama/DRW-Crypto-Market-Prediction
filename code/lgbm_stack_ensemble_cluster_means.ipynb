# %% [markdown]
# ### Layered LightGBM Ensemble: Time-Sliced Training on Clustered Features and Ridge Stacking
#
# In this notebook, I use the hierarchical clustering performed on the masked features in the feature_engineering notebook and aggregate the features in each cluster by taking the simple average of all features in the cluster. I experimented with alternative aggregation methods, such as weighted averages, but they did not provide any improvement over the plain average. The order book features are then added to these 174 masked aggregate features for training the boosted trees.
#
# The training data is split into 80% training and 20% validation. Because of the time-series nature of the data, the dataset is first sorted by time, with the earliest 80% used for training and the latest 20% reserved for validation. Both the training and validation sets are further divided into 20 subsamples by selecting every 20th row into a distinct slice. Each slice is used to train and tune a boosted tree. Finally, to ensemble their outputs, I train a ridge regression model on the predictions from all trees.

# %%
# libraries and settings
import gc
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import linkage, fcluster
from scipy.spatial.distance import squareform
from scipy.stats import pearsonr
from sklearn.linear_model import Ridge
import lightgbm as lgb
import optuna
import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_parquet('../data/input/train.parquet')
df_test = pd.read_parquet('../data/input/test.parquet')

# %%
# Clustering the features
X_cols = df_train.columns[df_train.columns.str.startswith('X')]
clusters = pd.Series(pd.read_csv('../data/intermediate/clusters.csv', index_col = 0).iloc[:,0])

# Group columns by cluster and take the mean across features inside each cluster
df_reduced = (
    df_train[X_cols].groupby(clusters, axis=1)
      .mean()
    #   .sort_index(axis=1) 
)

df_reduced.set_index(df_train.index, inplace = True)
df_reduced = pd.merge(
    df_train[['bid_qty', 'ask_qty', 'buy_qty', 'sell_qty', 'volume', 'label']],
    df_reduced,
    left_index = True, 
    right_index = True
)


df_reduced_test = (
    df_test[X_cols].groupby(clusters, axis=1)
      .mean()
    #   .sort_index(axis=1) 
)

df_reduced_test.set_index(df_test.index, inplace = True)
df_reduced_test = pd.merge(
    df_test[['bid_qty', 'ask_qty', 'buy_qty', 'sell_qty', 'volume']],
    df_reduced_test,
    left_index = True, 
    right_index = True
)

# %% [markdown]
# #### Ensemble Prediction Model
# I design a class to pipeline the tuning and training procedures. First, the training and validation datasets are split into 20 subsamples by selecting every 20th row (after sorting teh data based on their timestamps) into each subsample. For each subsample, I train a boosted tree on the corresponding training data, tuning them on their paired validation subsample using the correlation metric. The correlation metric is chosen because it was the evaluation metric used in the competition.
#
# Once all 20 tuned trees are trained, I generate predictions from them on the full training and validation datasets. These stacked predictions form the inputs to a ridge regression model, which is trained on the training predictions. The ridge regularization parameter is tuned based on the correlation metric evaluated on the validation predictions.
#
# Finally, after identifying the optimal ridge parameter, I retrain all boosted trees with their tuned hyperparameters on the full dataset (including the validation sample). I then refit the ridge regression using the optimized regularization parameter on the stacked predictions from the full data. This final ensemble model is used to produce predictions on the test dataset.

# %%
""" **************** ENSEMBLE MODEL ****************** """
class LightGBMTimeSeriesEnsemble:
    def __init__(self, n_models, n_trials, alphas=None, metric='rmse', random_seed=42):
        """
        n_models  : number of base learners (e.g. 50)
        n_trials  : Optuna trials per learner
        alphas    : candidate ridge regularization strengths
        metric    : LightGBM eval metric (for early stopping)
        """
        self.n_models = n_models
        self.n_trials = n_trials
        self.metric = metric
        self.alphas = alphas if alphas is not None else np.logspace(-2, 5, 30)
        self.seed = random_seed

        self.best_params_list = []
        self.best_iterations = []
        self.models = []
        self.ridge = None
        self.best_alpha = None

    def _optuna_objective(self, trial, X_tr, y_tr, X_val, y_val):
        params = {
            'objective': 'regression',
            'metric': 'rmse',  
            'verbosity': -1,
            'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.1, log=True),
            'num_leaves': trial.suggest_int('num_leaves', 16, 64),
            'max_depth': trial.suggest_int('max_depth', 2, 6),
            'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 100),
            'feature_fraction': trial.suggest_float('feature_fraction', 0.1, 0.5),
            'bagging_fraction': trial.suggest_float('bagging_fraction', 0.2, 0.6),
            'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
            'lambda_l1': trial.suggest_float('lambda_l1', 0.0, 5.0),
            'lambda_l2': trial.suggest_float('lambda_l2', 0.0, 5.0),
            'num_boost_round': trial.suggest_int('num_boost_round', 200,500),
            'early_stopping_rounds': 50
        }
        model = lgb.train(
            params,
            lgb.Dataset(X_tr, y_tr),
            valid_sets=[lgb.Dataset(X_val, y_val)]
        )
        pred = model.predict(X_val)
        corr, _ = pearsonr(pred, y_val)
        return -corr

    def fit(self, X_train, y_train, X_val, y_val):
        """
        1) Fit each base model on X_train[i::n] versus y_train[i::n] with Optuna tuning.
        Next steps are carried out in the fit_ridge function:
        2) Make predictions of each base model on *full* X_train => (n_samples_train x n_models)
        3) Ridge-fit on (train_preds, y_train)
        4) Select alpha by evaluating ridge on full X_val predictions
        """
        self.models = []
        self.best_params_list = []
        self.best_iterations = []

        
        for i in range(self.n_models):
            print(f'Training model {i+1}/{self.n_models}')
            Xt = X_train.iloc[i::self.n_models]
            yt = y_train.iloc[i::self.n_models]
            Xv = X_val.iloc[i::self.n_models]
            yv = y_val.iloc[i::self.n_models]

            # Tune
            sampler = optuna.samplers.TPESampler(seed=self.seed)
            study = optuna.create_study(direction='minimize', sampler=sampler)
            study.optimize(
                lambda trial: self._optuna_objective(trial, Xt, yt, Xv, yv),
                n_trials=self.n_trials,
            )
            best_params = study.best_params
            best_params['seed'] = self.seed
            

            # Train model with best params
            model = lgb.train(
                {
                **best_params, 
                'objective':'regression',
                'metric':self.metric,
                'verbosity':-1, 
                'early_stopping_rounds': 50
                },
                lgb.Dataset(Xt, yt),
                valid_sets=[lgb.Dataset(Xv, yv)]
            )
            best_params['num_boost_round'] = model.best_iteration
            self.best_params_list.append(best_params)
            self.best_iterations.append(model.best_iteration)
            self.models.append(model)

        self.fit_ridge(X_train, y_train, X_val, y_val, self.alphas)
        
        
    def fit_ridge(self, X_train, y_train, X_val, y_val, alphas):
        """
        1) Make predictions of each base model on *full* X_train => (n_samples_train x n_models)
        2) Ridge-fit on (train_preds, y_train)
        3) Select alpha by evaluating ridge on full X_val predictions
        """
        # --- predictions on full training set ---
        train_stack = np.column_stack([m.predict(X_train, num_iteration=it)
                                       for m, it in zip(self.models, self.best_iterations)])

        # --- search alpha by evaluating on validation set ---
        val_stack = np.column_stack([m.predict(X_val, num_iteration=it)
                                     for m, it in zip(self.models, self.best_iterations)])

        self.alphas = alphas
        best_corr = -np.inf
        for a in self.alphas:
            r = Ridge(alpha=a)
            r.fit(train_stack, y_train)
            corr, _ = pearsonr(r.predict(val_stack), y_val)
            print(f' ridge alpha: {a:.5f}, val corr: {corr:.5f}')
            if corr > best_corr:
                best_corr = corr
                self.best_alpha = a
                self.ridge = r

        print(f'Best ridge alpha: {self.best_alpha:.5f}, val corr: {best_corr:.5f}')
    
    
    def refit_full(self, X_full, y_full):
        """
        Retrain base models and the ridge regression model on full data using best params and alpha.
        """
        self.models = []
        for i, params in enumerate(self.best_params_list):
            print(f'Refitting model {i+1}/{self.n_models} on full data...')
            model = lgb.train(
                {
                **params,  
                'objective':'regression',
                'metric':self.metric,
                'verbosity':-1
                },
                lgb.Dataset(X_full, y_full)
            )
            self.models.append(model)
        
        full_stack = np.column_stack([
            m.predict(X_full, num_iteration=it) for m, it in zip(self.models, self.best_iterations)
        ])
        self.ridge = Ridge(alpha=self.best_alpha)
        self.ridge.fit(full_stack, y_full)

    def predict(self, X):
        """
        Predict stacked output on full dataset X
        """
        base = np.column_stack([m.predict(X, num_iteration=it)
                                for m, it in zip(self.models, self.best_iterations)])
        return self.ridge.predict(base)

# %%
df_reduced.sort_index(inplace = True)
n_train = round(df_reduced.shape[0]*0.8)
X_train = df_reduced.iloc[:n_train].drop(columns = ['label'])
X_val = df_reduced.iloc[n_train:].drop(columns = ['label'])
y_train = df_reduced.iloc[:n_train]['label'] 
y_val = df_reduced.iloc[n_train:]['label'] 

ensemble = LightGBMTimeSeriesEnsemble(n_models=20, n_trials=50)
ensemble.fit(X_train, y_train, X_val, y_val)
# Out:
# [I 2025-08-17 23:53:55,199] A new study created in memory with name: no-name-736ef66f-4529-46a0-b69c-d58d9e9e04d8
# Training model 1/20
# [I 2025-08-17 23:53:55,594] Trial 0 finished with value: -0.08518368256045201 and parameters: {'learning_rate': 0.015355286838886862, 'num_leaves': 62, 'max_depth': 5, 'min_data_in_leaf': 64, 'feature_fraction': 0.1624074561769746, 'bagging_fraction': 0.26239780813448105, 'bagging_freq': 1, 'lambda_l1': 4.330880728874676, 'lambda_l2': 3.005575058716044, 'num_boost_round': 413}. Best is trial 0 with value: -0.08518368256045201.
# [I 2025-08-17 23:53:55,982] Trial 1 finished with value: -0.0922343442823971 and parameters: {'learning_rate': 0.005318033256270142, 'num_leaves': 63, 'max_depth': 6, 'min_data_in_leaf': 29, 'feature_fraction': 0.17272998688284025, 'bagging_fraction': 0.27336180394137355, 'bagging_freq': 4, 'lambda_l1': 2.6237821581611893, 'lambda_l2': 2.1597250932105787, 'num_boost_round': 287}. Best is trial 1 with value: -0.0922343442823971.
# [I 2025-08-17 23:53:56,249] Trial 2 finished with value: -0.07961012521227545 and parameters: {'learning_rate': 0.03126143958203108, 'num_leaves': 22, 'max_depth': 3, 'min_data_in_leaf': 43, 'feature_fraction': 0.28242799368681437, 'bagging_fraction': 0.5140703845572054, 'bagging_freq': 2, 'lambda_l1': 2.571172192068058, 'lambda_l2': 2.9620728443102124, 'num_boost_round': 213}. Best is trial 1 with value: -0.0922343442823971.
# [I 2025-08-17 23:53:56,542] Trial 3 finished with value: -0.11077411068168361 and parameters: {'learning_rate': 0.030860579740535368, 'num_leaves': 24, 'max_depth': 2, 'min_data_in_leaf': 96, 'feature_fraction': 0.4862528132298237, 'bagging_fraction': 0.5233589392465845, 'bagging_freq': 4, 'lambda_l1': 0.48836057003191935, 'lambda_l2': 3.4211651325607844, 'num_boost_round': 332}. Best is trial 3 with value: -0.11077411068168361.
# [I 2025-08-17 23:53:56,835] Trial 4 finished with value: -0.10181195982720259 and parameters: {'learning_rate': 0.007206848764305203, 'num_leaves': 40, 'max_depth': 2, 'min_data_in_leaf': 92, 'feature_fraction': 0.20351199264000677, 'bagging_fraction': 0.46500891374159276, 'bagging_freq': 4, 'lambda_l1': 2.600340105889054, 'lambda_l2': 2.7335513967163982, 'num_boost_round': 255}. Best is trial 3 with value: -0.11077411068168361.
# [I 2025-08-17 23:53:57,168] Trial 5 finished with value: -0.07816856356999867 and parameters: {'learning_rate': 0.09129115219600122, 'num_leaves': 53, 'max_depth': 6, 'min_data_in_leaf': 91, 'feature_fraction': 0.3391599915244341, 'bagging_fraction': 0.5687496940092467, 'bagging_freq': 1, 'lambda_l1': 0.979914312095726, 'lambda_l2': 0.22613644455269033, 'num_boost_round': 297}. Best is trial 3 with value: -0.11077411068168361.
# [I 2025-08-17 23:53:57,616] Trial 6 finished with value: -0.0925645565112432 and parameters: {'learning_rate': 0.016019568611465234, 'num_leaves': 29, 'max_depth': 6, 'min_data_in_leaf': 42, 'feature_fraction': 0.2123738038749523, 'bagging_fraction': 0.4170784332632994, 'bagging_freq': 2, 'lambda_l1': 4.010984903770199, 'lambda_l2': 0.3727532183988541, 'num_boost_round': 497}. Best is trial 3 with value: -0.11077411068168361.
# [I 2025-08-17 23:53:57,887] Trial 7 finished with value: -0.08064360758358713 and parameters: {'learning_rate': 0.05054562991054155, 'num_leaves': 25, 'max_depth': 2, 'min_data_in_leaf': 84, 'feature_fraction': 0.38274293753904687, 'bagging_fraction': 0.4916028672163949, 'bagging_freq': 8, 'lambda_l1': 0.3702232586704518, 'lambda_l2': 1.7923286427213632, 'num_boost_round': 234}. Best is trial 3 with value: -0.11077411068168361.
# [I 2025-08-17 23:53:58,137] Trial 8 finished with value: -0.06563380669041417 and parameters: {'learning_rate': 0.06635802485202448, 'num_leaves': 46, 'max_depth': 3, 'min_data_in_leaf': 15, 'feature_fraction': 0.2243929286862649, 'bagging_fraction': 0.33007332881069884, 'bagging_freq': 8, 'lambda_l1': 3.1877873567760657, 'lambda_l2': 4.436063712881633, 'num_boost_round': 342}. Best is trial 3 with value: -0.11077411068168361.
# [I 2025-08-17 23:53:58,578] Trial 9 finished with value: -0.1087294969152136 and parameters: {'learning_rate': 0.007154276249073926, 'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 61, 'feature_fraction': 0.40838687198182444, 'bagging_fraction': 0.3975182385457563, 'bagging_freq': 6, 'lambda_l1': 2.137705091792748, 'lambda_l2': 0.12709563372047594, 'num_boost_round': 232}. Best is trial 3 with value: -0.11077411068168361.
# [I 2025-08-17 23:53:58,939] Trial 10 finished with value: -0.08528169617953539 and parameters: {'learning_rate': 0.02893735554922835, 'num_leaves': 16, 'max_depth': 3, 'min_data_in_leaf': 74, 'feature_fraction': 0.4935584941681304, 'bagging_fraction': 0.5630659181130071, 'bagging_freq': 10, 'lambda_l1': 1.3814300977777596, 'lambda_l2': 4.753074624888008, 'num_boost_round': 393}. Best is trial 3 with value: -0.11077411068168361.
# [I 2025-08-17 23:53:59,323] Trial 11 finished with value: -0.11526323618891149 and parameters: {'learning_rate': 0.011589164115192143, 'num_leaves': 36, 'max_depth': 4, 'min_data_in_leaf': 100, 'feature_fraction': 0.49510636877179415, 'bagging_fraction': 0.36928034551399147, 'bagging_freq': 6, 'lambda_l1': 1.228076820742594, 'lambda_l2': 3.8978608446145016, 'num_boost_round': 355}. Best is trial 11 with value: -0.11526323618891149.
# [I 2025-08-17 23:53:59,713] Trial 12 finished with value: -0.1008551275700848 and parameters: {'learning_rate': 0.01298895638741627, 'num_leaves': 34, 'max_depth': 4, 'min_data_in_leaf': 97, 'feature_fraction': 0.49654600734801935, 'bagging_fraction': 0.3651456263915391, 'bagging_freq': 5, 'lambda_l1': 0.12370400520775271, 'lambda_l2': 4.234980616943328, 'num_boost_round': 355}. Best is trial 11 with value: -0.11526323618891149.
# [I 2025-08-17 23:54:00,091] Trial 13 finished with value: -0.07128891823880906 and parameters: {'learning_rate': 0.024436766633555408, 'num_leaves': 36, 'max_depth': 4, 'min_data_in_leaf': 100, 'feature_fraction': 0.4375920406844781, 'bagging_fraction': 0.32401489084224055, 'bagging_freq': 7, 'lambda_l1': 1.327148291428597, 'lambda_l2': 3.909060420503994, 'num_boost_round': 422}. Best is trial 11 with value: -0.11526323618891149.
# [I 2025-08-17 23:54:00,453] Trial 14 finished with value: -0.08849566689299711 and parameters: {'learning_rate': 0.0452005061953544, 'num_leaves': 30, 'max_depth': 2, 'min_data_in_leaf': 77, 'feature_fraction': 0.4371096338372517, 'bagging_fraction': 0.4498265183008335, 'bagging_freq': 5, 'lambda_l1': 0.736494341677159, 'lambda_l2': 3.5550948765822015, 'num_boost_round': 342}. Best is trial 11 with value: -0.11526323618891149.
# [I 2025-08-17 23:54:00,811] Trial 15 finished with value: -0.08644652482922974 and parameters: {'learning_rate': 0.010854067713074024, 'num_leaves': 21, 'max_depth': 5, 'min_data_in_leaf': 74, 'feature_fraction': 0.10189604786123588, 'bagging_fraction': 0.20836542659336157, 'bagging_freq': 3, 'lambda_l1': 1.8672477774655822, 'lambda_l2': 1.2752853460694804, 'num_boost_round': 458}. Best is trial 11 with value: -0.11526323618891149.
# [I 2025-08-17 23:54:01,122] Trial 16 finished with value: -0.09906901584446284 and parameters: {'learning_rate': 0.02046721692019477, 'num_leaves': 43, 'max_depth': 3, 'min_data_in_leaf': 84, 'feature_fraction': 0.3343872902276028, 'bagging_fraction': 0.5117772967102288, 'bagging_freq': 6, 'lambda_l1': 0.07446334459789683, 'lambda_l2': 4.98948896324673, 'num_boost_round': 296}. Best is trial 11 with value: -0.11526323618891149.
# [I 2025-08-17 23:54:01,523] Trial 17 finished with value: -0.098076739630766 and parameters: {'learning_rate': 0.01061034983232118, 'num_leaves': 35, 'max_depth': 4, 'min_data_in_leaf': 49, 'feature_fraction': 0.45488386580255086, 'bagging_fraction': 0.413343865084102, 'bagging_freq': 9, 'lambda_l1': 1.7455198366464997, 'lambda_l2': 3.6277148318110735, 'num_boost_round': 388}. Best is trial 11 with value: -0.11526323618891149.
# [I 2025-08-17 23:54:01,820] Trial 18 finished with value: -0.07966912849514302 and parameters: {'learning_rate': 0.038978896944118505, 'num_leaves': 16, 'max_depth': 2, 'min_data_in_leaf': 86, 'feature_fraction': 0.3831641487157895, 'bagging_fraction': 0.585719886554112, 'bagging_freq': 4, 'lambda_l1': 0.6411081345826529, 'lambda_l2': 3.280528539603945, 'num_boost_round': 330}. Best is trial 11 with value: -0.11526323618891149.
# [I 2025-08-17 23:54:02,165] Trial 19 finished with value: -0.11187428856769813 and parameters: {'learning_rate': 0.018915137025867522, 'num_leaves': 26, 'max_depth': 3, 'min_data_in_leaf': 66, 'feature_fraction': 0.27492467509048235, 'bagging_fraction': 0.3590602526122234, 'bagging_freq': 7, 'lambda_l1': 4.906565433791467, 'lambda_l2': 2.2774289832365398, 'num_boost_round': 364}. Best is trial 11 with value: -0.11526323618891149.
# [I 2025-08-17 23:54:02,518] Trial 20 finished with value: -0.09347897092824098 and parameters: {'learning_rate': 0.019475166705653572, 'num_leaves': 29, 'max_depth': 4, 'min_data_in_leaf': 64, 'feature_fraction': 0.28499481265042315, 'bagging_fraction': 0.3484127055300137, 'bagging_freq': 7, 'lambda_l1': 3.2583381030203125, 'lambda_l2': 1.1985036679100785, 'num_boost_round': 371}. Best is trial 11 with value: -0.11526323618891149.
# [I 2025-08-17 23:54:02,893] Trial 21 finished with value: -0.09613587117249955 and parameters: {'learning_rate': 0.0090533553708613, 'num_leaves': 24, 'max_depth': 3, 'min_data_in_leaf': 98, 'feature_fraction': 0.3447857500011979, 'bagging_fraction': 0.36749003358747556, 'bagging_freq': 7, 'lambda_l1': 3.6386877683560535, 'lambda_l2': 2.4480027214424918, 'num_boost_round': 432}. Best is trial 11 with value: -0.11526323618891149.
# [I 2025-08-17 23:54:03,212] Trial 22 finished with value: -0.06861221494875455 and parameters: {'learning_rate': 0.03103014965252582, 'num_leaves': 29, 'max_depth': 3, 'min_data_in_leaf': 78, 'feature_fraction': 0.4710366447973371, 'bagging_fraction': 0.2974040046404778, 'bagging_freq': 6, 'lambda_l1': 4.997067470438426, 'lambda_l2': 4.001432230386708, 'num_boost_round': 318}. Best is trial 11 with value: -0.11526323618891149.
# [I 2025-08-17 23:54:03,539] Trial 23 finished with value: -0.09433583928975313 and parameters: {'learning_rate': 0.01839297908944334, 'num_leaves': 38, 'max_depth': 2, 'min_data_in_leaf': 56, 'feature_fraction': 0.25739344515714807, 'bagging_fraction': 0.43931878251412, 'bagging_freq': 5, 'lambda_l1': 1.1369348444829779, 'lambda_l2': 2.14361417339687, 'num_boost_round': 374}. Best is trial 11 with value: -0.11526323618891149.
# [I 2025-08-17 23:54:03,904] Trial 24 finished with value: -0.1154356188970884 and parameters: {'learning_rate': 0.013627209957756146, 'num_leaves': 32, 'max_depth': 4, 'min_data_in_leaf': 34, 'feature_fraction': 0.3138240750176763, 'bagging_fraction': 0.395148714953341, 'bagging_freq': 8, 'lambda_l1': 4.8776826721834095, 'lambda_l2': 3.325873147129733, 'num_boost_round': 319}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:04,261] Trial 25 finished with value: -0.10234814012902421 and parameters: {'learning_rate': 0.012841581245004115, 'num_leaves': 42, 'max_depth': 4, 'min_data_in_leaf': 30, 'feature_fraction': 0.3094442673327746, 'bagging_fraction': 0.3840027300078946, 'bagging_freq': 8, 'lambda_l1': 4.76092378583839, 'lambda_l2': 1.809685208728848, 'num_boost_round': 259}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:04,724] Trial 26 finished with value: -0.10801004631070273 and parameters: {'learning_rate': 0.007766169340361569, 'num_leaves': 32, 'max_depth': 5, 'min_data_in_leaf': 10, 'feature_fraction': 0.25884398940107023, 'bagging_fraction': 0.31100729532051963, 'bagging_freq': 10, 'lambda_l1': 4.492471832693887, 'lambda_l2': 3.1220522564327347, 'num_boost_round': 315}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:05,132] Trial 27 finished with value: -0.09464172031069493 and parameters: {'learning_rate': 0.013771439124010416, 'num_leaves': 38, 'max_depth': 4, 'min_data_in_leaf': 27, 'feature_fraction': 0.37763824648963107, 'bagging_fraction': 0.22341137340946252, 'bagging_freq': 9, 'lambda_l1': 3.8836310788869066, 'lambda_l2': 2.6881302029311023, 'num_boost_round': 371}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:05,567] Trial 28 finished with value: -0.07593799770153858 and parameters: {'learning_rate': 0.005256453964045537, 'num_leaves': 47, 'max_depth': 4, 'min_data_in_leaf': 39, 'feature_fraction': 0.10824654450008506, 'bagging_fraction': 0.3597252211041961, 'bagging_freq': 9, 'lambda_l1': 3.12569796520109, 'lambda_l2': 3.8305764186133247, 'num_boost_round': 450}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:05,919] Trial 29 finished with value: -0.07346805907973034 and parameters: {'learning_rate': 0.016654241487843165, 'num_leaves': 53, 'max_depth': 5, 'min_data_in_leaf': 68, 'feature_fraction': 0.1451800995386303, 'bagging_fraction': 0.2963883932457978, 'bagging_freq': 7, 'lambda_l1': 4.379714704573339, 'lambda_l2': 4.469132354417651, 'num_boost_round': 401}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:06,264] Trial 30 finished with value: -0.09462332445366833 and parameters: {'learning_rate': 0.0235959525640269, 'num_leaves': 57, 'max_depth': 3, 'min_data_in_leaf': 22, 'feature_fraction': 0.31267187862554413, 'bagging_fraction': 0.2536791860341914, 'bagging_freq': 8, 'lambda_l1': 4.96769089688219, 'lambda_l2': 2.9106385015680987, 'num_boost_round': 279}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:06,658] Trial 31 finished with value: -0.10549423159842179 and parameters: {'learning_rate': 0.010176233062056651, 'num_leaves': 26, 'max_depth': 3, 'min_data_in_leaf': 51, 'feature_fraction': 0.42511213204333076, 'bagging_fraction': 0.4179325304638881, 'bagging_freq': 6, 'lambda_l1': 4.07137492728728, 'lambda_l2': 3.4329020270522492, 'num_boost_round': 356}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:06,994] Trial 32 finished with value: -0.10325519934544171 and parameters: {'learning_rate': 0.023520070425111433, 'num_leaves': 26, 'max_depth': 2, 'min_data_in_leaf': 91, 'feature_fraction': 0.47893450875793425, 'bagging_fraction': 0.3904276674623689, 'bagging_freq': 3, 'lambda_l1': 4.608679045795249, 'lambda_l2': 2.429338564613191, 'num_boost_round': 320}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:07,385] Trial 33 finished with value: -0.09336875446234336 and parameters: {'learning_rate': 0.014377932748490077, 'num_leaves': 20, 'max_depth': 4, 'min_data_in_leaf': 34, 'feature_fraction': 0.23949838023531722, 'bagging_fraction': 0.4805849932390285, 'bagging_freq': 5, 'lambda_l1': 0.4865415420100646, 'lambda_l2': 3.213249199669012, 'num_boost_round': 304}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:07,755] Trial 34 finished with value: -0.07490557044278973 and parameters: {'learning_rate': 0.027903099110996338, 'num_leaves': 33, 'max_depth': 3, 'min_data_in_leaf': 69, 'feature_fraction': 0.16893975275517445, 'bagging_fraction': 0.5391087141777005, 'bagging_freq': 4, 'lambda_l1': 2.103435493235871, 'lambda_l2': 3.7028231295143823, 'num_boost_round': 282}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:08,107] Trial 35 finished with value: -0.10937254766743039 and parameters: {'learning_rate': 0.03584103260056033, 'num_leaves': 19, 'max_depth': 2, 'min_data_in_leaf': 93, 'feature_fraction': 0.40786258002866194, 'bagging_fraction': 0.4381344378074359, 'bagging_freq': 3, 'lambda_l1': 2.859362754355116, 'lambda_l2': 2.8512480340852093, 'num_boost_round': 333}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:08,502] Trial 36 finished with value: -0.09593557004601659 and parameters: {'learning_rate': 0.016961170143062743, 'num_leaves': 23, 'max_depth': 4, 'min_data_in_leaf': 56, 'feature_fraction': 0.46309997900142363, 'bagging_fraction': 0.2654315742046463, 'bagging_freq': 7, 'lambda_l1': 0.8304960730659419, 'lambda_l2': 4.170605452237702, 'num_boost_round': 357}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:08,956] Trial 37 finished with value: -0.08787725715311039 and parameters: {'learning_rate': 0.00638767621230689, 'num_leaves': 30, 'max_depth': 3, 'min_data_in_leaf': 47, 'feature_fraction': 0.19607828357224605, 'bagging_fraction': 0.3450564367928737, 'bagging_freq': 4, 'lambda_l1': 1.5753205512948523, 'lambda_l2': 2.1392600582323635, 'num_boost_round': 381}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:09,330] Trial 38 finished with value: -0.09272946935488417 and parameters: {'learning_rate': 0.06527746040697228, 'num_leaves': 27, 'max_depth': 6, 'min_data_in_leaf': 82, 'feature_fraction': 0.3562951644853183, 'bagging_fraction': 0.38638226139814696, 'bagging_freq': 1, 'lambda_l1': 2.4104675764247143, 'lambda_l2': 3.35958594367641, 'num_boost_round': 408}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:09,693] Trial 39 finished with value: -0.10618083585914515 and parameters: {'learning_rate': 0.021571602709721298, 'num_leaves': 32, 'max_depth': 2, 'min_data_in_leaf': 89, 'feature_fraction': 0.27705841940590714, 'bagging_fraction': 0.46568502336576806, 'bagging_freq': 8, 'lambda_l1': 4.262870175969847, 'lambda_l2': 1.8377846860194764, 'num_boost_round': 271}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:10,137] Trial 40 finished with value: -0.11233776336930212 and parameters: {'learning_rate': 0.011515351531423851, 'num_leaves': 38, 'max_depth': 5, 'min_data_in_leaf': 39, 'feature_fraction': 0.4011566461207167, 'bagging_fraction': 0.4205911748823574, 'bagging_freq': 6, 'lambda_l1': 0.3257698615342275, 'lambda_l2': 1.2348730220594761, 'num_boost_round': 309}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:10,604] Trial 41 finished with value: -0.10247918758927035 and parameters: {'learning_rate': 0.011419026701607446, 'num_leaves': 38, 'max_depth': 5, 'min_data_in_leaf': 38, 'feature_fraction': 0.44535706135794406, 'bagging_fraction': 0.4185790376615577, 'bagging_freq': 6, 'lambda_l1': 0.4084266495266966, 'lambda_l2': 0.7203303277520687, 'num_boost_round': 306}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:11,213] Trial 42 finished with value: -0.07654693629061948 and parameters: {'learning_rate': 0.0089054988588901, 'num_leaves': 42, 'max_depth': 6, 'min_data_in_leaf': 22, 'feature_fraction': 0.40597482830538467, 'bagging_fraction': 0.5239667425546877, 'bagging_freq': 7, 'lambda_l1': 1.0940138531900916, 'lambda_l2': 0.8019807727798767, 'num_boost_round': 336}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:11,609] Trial 43 finished with value: -0.11269196511615284 and parameters: {'learning_rate': 0.014661926106018623, 'num_leaves': 36, 'max_depth': 5, 'min_data_in_leaf': 45, 'feature_fraction': 0.326348701370046, 'bagging_fraction': 0.3359119044833257, 'bagging_freq': 6, 'lambda_l1': 0.40331710289263256, 'lambda_l2': 1.626862522872955, 'num_boost_round': 355}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:12,027] Trial 44 finished with value: -0.10468226860949509 and parameters: {'learning_rate': 0.011965770207578, 'num_leaves': 36, 'max_depth': 5, 'min_data_in_leaf': 42, 'feature_fraction': 0.3286065526860316, 'bagging_fraction': 0.32264291183894145, 'bagging_freq': 6, 'lambda_l1': 0.9176833332771799, 'lambda_l2': 1.0057387870315422, 'num_boost_round': 354}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:12,400] Trial 45 finished with value: -0.07708155744719696 and parameters: {'learning_rate': 0.015109312433567024, 'num_leaves': 40, 'max_depth': 5, 'min_data_in_leaf': 32, 'feature_fraction': 0.3623669025579512, 'bagging_fraction': 0.3429711538482921, 'bagging_freq': 7, 'lambda_l1': 0.005442613969263488, 'lambda_l2': 1.4252447823261116, 'num_boost_round': 322}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:12,834] Trial 46 finished with value: -0.09239984928179568 and parameters: {'learning_rate': 0.009170400003309572, 'num_leaves': 47, 'max_depth': 5, 'min_data_in_leaf': 38, 'feature_fraction': 0.3173638013273289, 'bagging_fraction': 0.37395828956083144, 'bagging_freq': 5, 'lambda_l1': 0.2888099453352653, 'lambda_l2': 1.523193689930107, 'num_boost_round': 345}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:13,241] Trial 47 finished with value: -0.09343702724080846 and parameters: {'learning_rate': 0.017900265558048068, 'num_leaves': 44, 'max_depth': 5, 'min_data_in_leaf': 44, 'feature_fraction': 0.27646518096952816, 'bagging_fraction': 0.28163223621793365, 'bagging_freq': 8, 'lambda_l1': 1.3334929837396365, 'lambda_l2': 1.577786050191758, 'num_boost_round': 365}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:13,808] Trial 48 finished with value: -0.10577840788544102 and parameters: {'learning_rate': 0.006169769970701693, 'num_leaves': 36, 'max_depth': 6, 'min_data_in_leaf': 35, 'feature_fraction': 0.29544224082433773, 'bagging_fraction': 0.40537170197396794, 'bagging_freq': 6, 'lambda_l1': 0.6430126972181894, 'lambda_l2': 1.991478869020428, 'num_boost_round': 292}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:14,177] Trial 49 finished with value: -0.09186465093372206 and parameters: {'learning_rate': 0.015030357592309538, 'num_leaves': 31, 'max_depth': 4, 'min_data_in_leaf': 26, 'feature_fraction': 0.24936617390224305, 'bagging_fraction': 0.3533961444898315, 'bagging_freq': 5, 'lambda_l1': 4.752312908898305, 'lambda_l2': 2.609363198730733, 'num_boost_round': 494}. Best is trial 24 with value: -0.1154356188970884.
# [I 2025-08-17 23:54:14,524] A new study created in memory with name: no-name-37b395f4-a354-483c-9448-250d1190aa78
# Training model 2/20
# [I 2025-08-17 23:54:14,862] Trial 0 finished with value: -0.10677102700565064 and parameters: {'learning_rate': 0.015355286838886862, 'num_leaves': 62, 'max_depth': 5, 'min_data_in_leaf': 64, 'feature_fraction': 0.1624074561769746, 'bagging_fraction': 0.26239780813448105, 'bagging_freq': 1, 'lambda_l1': 4.330880728874676, 'lambda_l2': 3.005575058716044, 'num_boost_round': 413}. Best is trial 0 with value: -0.10677102700565064.
# [I 2025-08-17 23:54:15,369] Trial 1 finished with value: -0.10277257671291347 and parameters: {'learning_rate': 0.005318033256270142, 'num_leaves': 63, 'max_depth': 6, 'min_data_in_leaf': 29, 'feature_fraction': 0.17272998688284025, 'bagging_fraction': 0.27336180394137355, 'bagging_freq': 4, 'lambda_l1': 2.6237821581611893, 'lambda_l2': 2.1597250932105787, 'num_boost_round': 287}. Best is trial 0 with value: -0.10677102700565064.
# [I 2025-08-17 23:54:15,641] Trial 2 finished with value: -0.11384222314486506 and parameters: {'learning_rate': 0.03126143958203108, 'num_leaves': 22, 'max_depth': 3, 'min_data_in_leaf': 43, 'feature_fraction': 0.28242799368681437, 'bagging_fraction': 0.5140703845572054, 'bagging_freq': 2, 'lambda_l1': 2.571172192068058, 'lambda_l2': 2.9620728443102124, 'num_boost_round': 213}. Best is trial 2 with value: -0.11384222314486506.
# [I 2025-08-17 23:54:15,946] Trial 3 finished with value: -0.10489287718864242 and parameters: {'learning_rate': 0.030860579740535368, 'num_leaves': 24, 'max_depth': 2, 'min_data_in_leaf': 96, 'feature_fraction': 0.4862528132298237, 'bagging_fraction': 0.5233589392465845, 'bagging_freq': 4, 'lambda_l1': 0.48836057003191935, 'lambda_l2': 3.4211651325607844, 'num_boost_round': 332}. Best is trial 2 with value: -0.11384222314486506.
# [I 2025-08-17 23:54:16,287] Trial 4 finished with value: -0.11689698708960788 and parameters: {'learning_rate': 0.007206848764305203, 'num_leaves': 40, 'max_depth': 2, 'min_data_in_leaf': 92, 'feature_fraction': 0.20351199264000677, 'bagging_fraction': 0.46500891374159276, 'bagging_freq': 4, 'lambda_l1': 2.600340105889054, 'lambda_l2': 2.7335513967163982, 'num_boost_round': 255}. Best is trial 4 with value: -0.11689698708960788.
# [I 2025-08-17 23:54:16,614] Trial 5 finished with value: -0.08775962294802472 and parameters: {'learning_rate': 0.09129115219600122, 'num_leaves': 53, 'max_depth': 6, 'min_data_in_leaf': 91, 'feature_fraction': 0.3391599915244341, 'bagging_fraction': 0.5687496940092467, 'bagging_freq': 1, 'lambda_l1': 0.979914312095726, 'lambda_l2': 0.22613644455269033, 'num_boost_round': 297}. Best is trial 4 with value: -0.11689698708960788.
# [I 2025-08-17 23:54:16,984] Trial 6 finished with value: -0.1086401791015787 and parameters: {'learning_rate': 0.016019568611465234, 'num_leaves': 29, 'max_depth': 6, 'min_data_in_leaf': 42, 'feature_fraction': 0.2123738038749523, 'bagging_fraction': 0.4170784332632994, 'bagging_freq': 2, 'lambda_l1': 4.010984903770199, 'lambda_l2': 0.3727532183988541, 'num_boost_round': 497}. Best is trial 4 with value: -0.11689698708960788.
# [I 2025-08-17 23:54:17,256] Trial 7 finished with value: -0.10198544262587533 and parameters: {'learning_rate': 0.05054562991054155, 'num_leaves': 25, 'max_depth': 2, 'min_data_in_leaf': 84, 'feature_fraction': 0.38274293753904687, 'bagging_fraction': 0.4916028672163949, 'bagging_freq': 8, 'lambda_l1': 0.3702232586704518, 'lambda_l2': 1.7923286427213632, 'num_boost_round': 234}. Best is trial 4 with value: -0.11689698708960788.
# [I 2025-08-17 23:54:17,558] Trial 8 finished with value: -0.028100375986582802 and parameters: {'learning_rate': 0.06635802485202448, 'num_leaves': 46, 'max_depth': 3, 'min_data_in_leaf': 15, 'feature_fraction': 0.2243929286862649, 'bagging_fraction': 0.33007332881069884, 'bagging_freq': 8, 'lambda_l1': 3.1877873567760657, 'lambda_l2': 4.436063712881633, 'num_boost_round': 342}. Best is trial 4 with value: -0.11689698708960788.
# [I 2025-08-17 23:54:18,176] Trial 9 finished with value: -0.12115720900472748 and parameters: {'learning_rate': 0.007154276249073926, 'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 61, 'feature_fraction': 0.40838687198182444, 'bagging_fraction': 0.3975182385457563, 'bagging_freq': 6, 'lambda_l1': 2.137705091792748, 'lambda_l2': 0.12709563372047594, 'num_boost_round': 232}. Best is trial 9 with value: -0.12115720900472748.
# [I 2025-08-17 23:54:18,748] Trial 10 finished with value: -0.12092186011740337 and parameters: {'learning_rate': 0.009312973023426376, 'num_leaves': 39, 'max_depth': 4, 'min_data_in_leaf': 68, 'feature_fraction': 0.45684783587593114, 'bagging_fraction': 0.35702745926069496, 'bagging_freq': 10, 'lambda_l1': 1.4452962979186792, 'lambda_l2': 1.0707918120697866, 'num_boost_round': 401}. Best is trial 9 with value: -0.12115720900472748.
# [I 2025-08-17 23:54:19,268] Trial 11 finished with value: -0.11956945242634243 and parameters: {'learning_rate': 0.008684356319196788, 'num_leaves': 37, 'max_depth': 4, 'min_data_in_leaf': 68, 'feature_fraction': 0.4586229109175456, 'bagging_fraction': 0.35729833417119294, 'bagging_freq': 10, 'lambda_l1': 1.473527568231323, 'lambda_l2': 1.0791802035644282, 'num_boost_round': 413}. Best is trial 9 with value: -0.12115720900472748.
# [I 2025-08-17 23:54:19,693] Trial 12 finished with value: -0.12540526136816282 and parameters: {'learning_rate': 0.01082864455060085, 'num_leaves': 49, 'max_depth': 4, 'min_data_in_leaf': 72, 'feature_fraction': 0.4087696049520285, 'bagging_fraction': 0.40019405533087815, 'bagging_freq': 7, 'lambda_l1': 1.7139964413315818, 'lambda_l2': 1.1713781380698236, 'num_boost_round': 400}. Best is trial 12 with value: -0.12540526136816282.
# [I 2025-08-17 23:54:20,159] Trial 13 finished with value: -0.12299633122849667 and parameters: {'learning_rate': 0.015599375166583758, 'num_leaves': 51, 'max_depth': 5, 'min_data_in_leaf': 77, 'feature_fraction': 0.39724433135673004, 'bagging_fraction': 0.4268810767187708, 'bagging_freq': 7, 'lambda_l1': 1.7478684691557769, 'lambda_l2': 0.9862625482541706, 'num_boost_round': 464}. Best is trial 12 with value: -0.12540526136816282.
# [I 2025-08-17 23:54:20,603] Trial 14 finished with value: -0.1301998175664298 and parameters: {'learning_rate': 0.01435294180721578, 'num_leaves': 55, 'max_depth': 5, 'min_data_in_leaf': 81, 'feature_fraction': 0.323628478477892, 'bagging_fraction': 0.41467916204667726, 'bagging_freq': 7, 'lambda_l1': 1.7622290552337951, 'lambda_l2': 1.2644655287262305, 'num_boost_round': 485}. Best is trial 14 with value: -0.1301998175664298.
# [I 2025-08-17 23:54:21,010] Trial 15 finished with value: -0.10611435080446072 and parameters: {'learning_rate': 0.012638467927064823, 'num_leaves': 57, 'max_depth': 4, 'min_data_in_leaf': 78, 'feature_fraction': 0.10189604786123588, 'bagging_fraction': 0.20836542659336157, 'bagging_freq': 6, 'lambda_l1': 3.3663589538233003, 'lambda_l2': 1.6399266073423122, 'num_boost_round': 458}. Best is trial 14 with value: -0.1301998175664298.
# [I 2025-08-17 23:54:21,423] Trial 16 finished with value: -0.09367221687091375 and parameters: {'learning_rate': 0.022439135034431273, 'num_leaves': 47, 'max_depth': 5, 'min_data_in_leaf': 77, 'feature_fraction': 0.32425974932776247, 'bagging_fraction': 0.45013812181030344, 'bagging_freq': 8, 'lambda_l1': 0.9591454894466063, 'lambda_l2': 1.6374529382141052, 'num_boost_round': 380}. Best is trial 14 with value: -0.1301998175664298.
# [I 2025-08-17 23:54:21,812] Trial 17 finished with value: -0.12192957978048247 and parameters: {'learning_rate': 0.023575336987182206, 'num_leaves': 57, 'max_depth': 3, 'min_data_in_leaf': 52, 'feature_fraction': 0.3595333168073409, 'bagging_fraction': 0.38399448354980736, 'bagging_freq': 9, 'lambda_l1': 2.0675804240014046, 'lambda_l2': 0.7379542010347508, 'num_boost_round': 451}. Best is trial 14 with value: -0.1301998175664298.
# [I 2025-08-17 23:54:22,289] Trial 18 finished with value: -0.11476197021214199 and parameters: {'learning_rate': 0.010957586084350624, 'num_leaves': 42, 'max_depth': 5, 'min_data_in_leaf': 48, 'feature_fraction': 0.27274311439987087, 'bagging_fraction': 0.30050450569538517, 'bagging_freq': 5, 'lambda_l1': 3.376518168413198, 'lambda_l2': 2.268302678751437, 'num_boost_round': 497}. Best is trial 14 with value: -0.1301998175664298.
# [I 2025-08-17 23:54:22,665] Trial 19 finished with value: -0.11015637172328666 and parameters: {'learning_rate': 0.03266540548786145, 'num_leaves': 34, 'max_depth': 4, 'min_data_in_leaf': 86, 'feature_fraction': 0.42300811414606776, 'bagging_fraction': 0.5614035607563235, 'bagging_freq': 7, 'lambda_l1': 4.906565433791467, 'lambda_l2': 4.969213925248544, 'num_boost_round': 436}. Best is trial 14 with value: -0.1301998175664298.
# [I 2025-08-17 23:54:23,173] Trial 20 finished with value: -0.1104063908321122 and parameters: {'learning_rate': 0.005573771950360281, 'num_leaves': 57, 'max_depth': 3, 'min_data_in_leaf': 99, 'feature_fraction': 0.29939652597561495, 'bagging_fraction': 0.4733028118432257, 'bagging_freq': 7, 'lambda_l1': 0.979967075573072, 'lambda_l2': 3.6738901466096086, 'num_boost_round': 355}. Best is trial 14 with value: -0.1301998175664298.
# [I 2025-08-17 23:54:23,658] Trial 21 finished with value: -0.11773325179062999 and parameters: {'learning_rate': 0.016250530943592637, 'num_leaves': 52, 'max_depth': 5, 'min_data_in_leaf': 77, 'feature_fraction': 0.3880045361639723, 'bagging_fraction': 0.42830217487941785, 'bagging_freq': 7, 'lambda_l1': 1.958778434342722, 'lambda_l2': 1.001229202217878, 'num_boost_round': 472}. Best is trial 14 with value: -0.1301998175664298.
# [I 2025-08-17 23:54:24,170] Trial 22 finished with value: -0.11614923755966848 and parameters: {'learning_rate': 0.01237867512467535, 'num_leaves': 46, 'max_depth': 5, 'min_data_in_leaf': 75, 'feature_fraction': 0.4285172586858075, 'bagging_fraction': 0.3710490622369551, 'bagging_freq': 5, 'lambda_l1': 1.5345048123626603, 'lambda_l2': 1.462403734726406, 'num_boost_round': 439}. Best is trial 14 with value: -0.1301998175664298.
# [I 2025-08-17 23:54:24,645] Trial 23 finished with value: -0.12472580701589611 and parameters: {'learning_rate': 0.01839297908944334, 'num_leaves': 17, 'max_depth': 4, 'min_data_in_leaf': 60, 'feature_fraction': 0.3608775194487168, 'bagging_fraction': 0.41569185909613704, 'bagging_freq': 9, 'lambda_l1': 1.8144867814285395, 'lambda_l2': 0.6347085974050595, 'num_boost_round': 474}. Best is trial 14 with value: -0.1301998175664298.
# [I 2025-08-17 23:54:25,091] Trial 24 finished with value: -0.12264471374872654 and parameters: {'learning_rate': 0.0209361863287513, 'num_leaves': 16, 'max_depth': 4, 'min_data_in_leaf': 58, 'feature_fraction': 0.35176052447603445, 'bagging_fraction': 0.3347355124936434, 'bagging_freq': 9, 'lambda_l1': 2.9624466590877465, 'lambda_l2': 0.581509230295326, 'num_boost_round': 480}. Best is trial 14 with value: -0.1301998175664298.
# [I 2025-08-17 23:54:25,485] Trial 25 finished with value: -0.10341435286409954 and parameters: {'learning_rate': 0.04031277476697205, 'num_leaves': 33, 'max_depth': 4, 'min_data_in_leaf': 70, 'feature_fraction': 0.25696703884388283, 'bagging_fraction': 0.4027109313039952, 'bagging_freq': 9, 'lambda_l1': 0.015876889174418762, 'lambda_l2': 2.0309090694325946, 'num_boost_round': 392}. Best is trial 14 with value: -0.1301998175664298.
# [I 2025-08-17 23:54:25,931] Trial 26 finished with value: -0.10131385185042877 and parameters: {'learning_rate': 0.020118867652236094, 'num_leaves': 16, 'max_depth': 4, 'min_data_in_leaf': 31, 'feature_fraction': 0.309036327071797, 'bagging_fraction': 0.44825135782825726, 'bagging_freq': 8, 'lambda_l1': 1.2714354178709513, 'lambda_l2': 1.3511581622390396, 'num_boost_round': 428}. Best is trial 14 with value: -0.1301998175664298.
# [I 2025-08-17 23:54:26,369] Trial 27 finished with value: -0.14023389963042446 and parameters: {'learning_rate': 0.009953136984268437, 'num_leaves': 44, 'max_depth': 3, 'min_data_in_leaf': 85, 'feature_fraction': 0.3644794202807794, 'bagging_fraction': 0.32118529780504873, 'bagging_freq': 6, 'lambda_l1': 2.2711084245059157, 'lambda_l2': 0.6137368055302913, 'num_boost_round': 380}. Best is trial 27 with value: -0.14023389963042446.
# [I 2025-08-17 23:54:26,813] Trial 28 finished with value: -0.14027249918089318 and parameters: {'learning_rate': 0.009061179369547895, 'num_leaves': 43, 'max_depth': 3, 'min_data_in_leaf': 84, 'feature_fraction': 0.4415025604559948, 'bagging_fraction': 0.3055580084764802, 'bagging_freq': 6, 'lambda_l1': 2.3443244421855303, 'lambda_l2': 1.305221789473105, 'num_boost_round': 367}. Best is trial 28 with value: -0.14027249918089318.
# [I 2025-08-17 23:54:27,306] Trial 29 finished with value: -0.1169004940400768 and parameters: {'learning_rate': 0.006675867174218517, 'num_leaves': 45, 'max_depth': 3, 'min_data_in_leaf': 85, 'feature_fraction': 0.4993134344664015, 'bagging_fraction': 0.23317015045130984, 'bagging_freq': 6, 'lambda_l1': 2.2628716316057784, 'lambda_l2': 2.4484702643147656, 'num_boost_round': 368}. Best is trial 28 with value: -0.14027249918089318.
# [I 2025-08-17 23:54:27,803] Trial 30 finished with value: -0.11646256439545742 and parameters: {'learning_rate': 0.009222762392546033, 'num_leaves': 43, 'max_depth': 3, 'min_data_in_leaf': 91, 'feature_fraction': 0.44736069765122244, 'bagging_fraction': 0.2909656176867118, 'bagging_freq': 5, 'lambda_l1': 4.025281681026828, 'lambda_l2': 0.015304490820084227, 'num_boost_round': 316}. Best is trial 28 with value: -0.14027249918089318.
# [I 2025-08-17 23:54:28,195] Trial 31 finished with value: -0.1440837394840364 and parameters: {'learning_rate': 0.012473704615423195, 'num_leaves': 59, 'max_depth': 3, 'min_data_in_leaf': 82, 'feature_fraction': 0.3791363474752787, 'bagging_fraction': 0.31529902920105046, 'bagging_freq': 6, 'lambda_l1': 2.8947620336737154, 'lambda_l2': 1.3130458004066385, 'num_boost_round': 368}. Best is trial 31 with value: -0.1440837394840364.
# [I 2025-08-17 23:54:28,603] Trial 32 finished with value: -0.13768999611308574 and parameters: {'learning_rate': 0.013358992697043326, 'num_leaves': 64, 'max_depth': 2, 'min_data_in_leaf': 83, 'feature_fraction': 0.37660675688280737, 'bagging_fraction': 0.24786836623880554, 'bagging_freq': 6, 'lambda_l1': 2.906985537678355, 'lambda_l2': 2.000370260958974, 'num_boost_round': 365}. Best is trial 31 with value: -0.1440837394840364.
# [I 2025-08-17 23:54:28,979] Trial 33 finished with value: -0.13903082876494702 and parameters: {'learning_rate': 0.00831082514596544, 'num_leaves': 62, 'max_depth': 2, 'min_data_in_leaf': 88, 'feature_fraction': 0.4341809514060786, 'bagging_fraction': 0.253577289144232, 'bagging_freq': 6, 'lambda_l1': 2.9515262695413034, 'lambda_l2': 2.1334561452863032, 'num_boost_round': 370}. Best is trial 31 with value: -0.1440837394840364.
# [I 2025-08-17 23:54:29,383] Trial 34 finished with value: -0.11604833807370349 and parameters: {'learning_rate': 0.005064357443636819, 'num_leaves': 62, 'max_depth': 2, 'min_data_in_leaf': 100, 'feature_fraction': 0.4728813801965873, 'bagging_fraction': 0.307547653982516, 'bagging_freq': 3, 'lambda_l1': 2.8695094362555364, 'lambda_l2': 2.754647061405614, 'num_boost_round': 329}. Best is trial 31 with value: -0.1440837394840364.
# [I 2025-08-17 23:54:29,792] Trial 35 finished with value: -0.12231252011880431 and parameters: {'learning_rate': 0.00858635469789829, 'num_leaves': 61, 'max_depth': 3, 'min_data_in_leaf': 91, 'feature_fraction': 0.4184905899687908, 'bagging_fraction': 0.26966508606508804, 'bagging_freq': 4, 'lambda_l1': 2.409346523369502, 'lambda_l2': 0.7499274817643079, 'num_boost_round': 312}. Best is trial 31 with value: -0.1440837394840364.
# [I 2025-08-17 23:54:30,211] Trial 36 finished with value: -0.12819627471032977 and parameters: {'learning_rate': 0.006532526547763605, 'num_leaves': 59, 'max_depth': 2, 'min_data_in_leaf': 94, 'feature_fraction': 0.44337238141004753, 'bagging_fraction': 0.32616134293732363, 'bagging_freq': 5, 'lambda_l1': 3.5870496256343016, 'lambda_l2': 3.1408003040185424, 'num_boost_round': 275}. Best is trial 31 with value: -0.1440837394840364.
# [I 2025-08-17 23:54:30,602] Trial 37 finished with value: -0.14648093586315125 and parameters: {'learning_rate': 0.011080377317856625, 'num_leaves': 60, 'max_depth': 3, 'min_data_in_leaf': 87, 'feature_fraction': 0.4723709390041479, 'bagging_fraction': 0.21668077599738014, 'bagging_freq': 6, 'lambda_l1': 2.6633909085719885, 'lambda_l2': 0.44728746521473306, 'num_boost_round': 347}. Best is trial 37 with value: -0.14648093586315125.
# [I 2025-08-17 23:54:31,027] Trial 38 finished with value: -0.10594647775557395 and parameters: {'learning_rate': 0.01083748307577163, 'num_leaves': 55, 'max_depth': 3, 'min_data_in_leaf': 64, 'feature_fraction': 0.4818520769453325, 'bagging_fraction': 0.21571694102019975, 'bagging_freq': 4, 'lambda_l1': 2.606323900274303, 'lambda_l2': 0.38661423462727074, 'num_boost_round': 344}. Best is trial 37 with value: -0.14648093586315125.
# [I 2025-08-17 23:54:31,474] Trial 39 finished with value: -0.11753690295950522 and parameters: {'learning_rate': 0.006020939330776717, 'num_leaves': 35, 'max_depth': 3, 'min_data_in_leaf': 96, 'feature_fraction': 0.36866460108267735, 'bagging_fraction': 0.28516215247266097, 'bagging_freq': 3, 'lambda_l1': 3.800884082088613, 'lambda_l2': 0.34030289781588186, 'num_boost_round': 417}. Best is trial 37 with value: -0.14648093586315125.
# [I 2025-08-17 23:54:31,923] Trial 40 finished with value: -0.10959721057639192 and parameters: {'learning_rate': 0.00790624203064526, 'num_leaves': 29, 'max_depth': 3, 'min_data_in_leaf': 88, 'feature_fraction': 0.4654325586167146, 'bagging_fraction': 0.31472849381876, 'bagging_freq': 5, 'lambda_l1': 2.36839095700575, 'lambda_l2': 0.8602470140552189, 'num_boost_round': 289}. Best is trial 37 with value: -0.14648093586315125.
# [I 2025-08-17 23:54:32,285] Trial 41 finished with value: -0.13130934505680758 and parameters: {'learning_rate': 0.010365778212266152, 'num_leaves': 60, 'max_depth': 2, 'min_data_in_leaf': 88, 'feature_fraction': 0.4406164551371903, 'bagging_fraction': 0.24475696218830278, 'bagging_freq': 6, 'lambda_l1': 2.870538245357063, 'lambda_l2': 1.6960443711451578, 'num_boost_round': 381}. Best is trial 37 with value: -0.14648093586315125.
# [I 2025-08-17 23:54:32,747] Trial 42 finished with value: -0.12349440829389666 and parameters: {'learning_rate': 0.007684972368857024, 'num_leaves': 64, 'max_depth': 2, 'min_data_in_leaf': 81, 'feature_fraction': 0.3975096306720978, 'bagging_fraction': 0.2614083180907912, 'bagging_freq': 6, 'lambda_l1': 2.6942127079706997, 'lambda_l2': 0.5497322224208474, 'num_boost_round': 375}. Best is trial 37 with value: -0.14648093586315125.
# [I 2025-08-17 23:54:33,116] Trial 43 finished with value: -0.14451112392811122 and parameters: {'learning_rate': 0.012017394444437167, 'num_leaves': 59, 'max_depth': 3, 'min_data_in_leaf': 94, 'feature_fraction': 0.49599354973941195, 'bagging_fraction': 0.27726425027291707, 'bagging_freq': 6, 'lambda_l1': 3.3576701866375624, 'lambda_l2': 1.415780316635086, 'num_boost_round': 354}. Best is trial 37 with value: -0.14648093586315125.
# [I 2025-08-17 23:54:33,462] Trial 44 finished with value: -0.14585897689597654 and parameters: {'learning_rate': 0.026761942785591245, 'num_leaves': 54, 'max_depth': 3, 'min_data_in_leaf': 95, 'feature_fraction': 0.4964726713867945, 'bagging_fraction': 0.2265657616189415, 'bagging_freq': 5, 'lambda_l1': 3.2203351538798035, 'lambda_l2': 1.3849220494361, 'num_boost_round': 352}. Best is trial 37 with value: -0.14648093586315125.
# [I 2025-08-17 23:54:33,813] Trial 45 finished with value: -0.12742293337176808 and parameters: {'learning_rate': 0.027439593835014542, 'num_leaves': 54, 'max_depth': 3, 'min_data_in_leaf': 96, 'feature_fraction': 0.48856105605500666, 'bagging_fraction': 0.2107480952337308, 'bagging_freq': 4, 'lambda_l1': 3.146068985417891, 'lambda_l2': 1.4259240589863125, 'num_boost_round': 354}. Best is trial 37 with value: -0.14648093586315125.
# [I 2025-08-17 23:54:34,190] Trial 46 finished with value: -0.1289310159279578 and parameters: {'learning_rate': 0.01744792108684873, 'num_leaves': 59, 'max_depth': 3, 'min_data_in_leaf': 100, 'feature_fraction': 0.494041035021062, 'bagging_fraction': 0.23168841730469217, 'bagging_freq': 3, 'lambda_l1': 4.31123738281305, 'lambda_l2': 1.8694553897373525, 'num_boost_round': 325}. Best is trial 37 with value: -0.14648093586315125.
# [I 2025-08-17 23:54:34,566] Trial 47 finished with value: -0.1340653217951554 and parameters: {'learning_rate': 0.025820730104554875, 'num_leaves': 49, 'max_depth': 3, 'min_data_in_leaf': 93, 'feature_fraction': 0.47058835885346345, 'bagging_fraction': 0.2751524408669729, 'bagging_freq': 5, 'lambda_l1': 3.6411892289576615, 'lambda_l2': 2.352633796838039, 'num_boost_round': 338}. Best is trial 37 with value: -0.14648093586315125.
# [I 2025-08-17 23:54:34,925] Trial 48 finished with value: -0.14014256449584445 and parameters: {'learning_rate': 0.011974089420547425, 'num_leaves': 58, 'max_depth': 3, 'min_data_in_leaf': 81, 'feature_fraction': 0.45719200428059437, 'bagging_fraction': 0.23032184854084137, 'bagging_freq': 5, 'lambda_l1': 3.1540016570631977, 'lambda_l2': 1.5163205475727493, 'num_boost_round': 301}. Best is trial 37 with value: -0.14648093586315125.
# [I 2025-08-17 23:54:35,263] Trial 49 finished with value: -0.08515763276821467 and parameters: {'learning_rate': 0.035453726866509515, 'num_leaves': 54, 'max_depth': 3, 'min_data_in_leaf': 20, 'feature_fraction': 0.48162134822075603, 'bagging_fraction': 0.3423539388415523, 'bagging_freq': 7, 'lambda_l1': 3.3758229560354414, 'lambda_l2': 1.1730279420713943, 'num_boost_round': 392}. Best is trial 37 with value: -0.14648093586315125.
# [I 2025-08-17 23:54:35,594] A new study created in memory with name: no-name-5278a063-f7da-428f-9256-5b19ceefd288
# Training model 3/20
# [I 2025-08-17 23:54:35,915] Trial 0 finished with value: -0.07832794650006403 and parameters: {'learning_rate': 0.015355286838886862, 'num_leaves': 62, 'max_depth': 5, 'min_data_in_leaf': 64, 'feature_fraction': 0.1624074561769746, 'bagging_fraction': 0.26239780813448105, 'bagging_freq': 1, 'lambda_l1': 4.330880728874676, 'lambda_l2': 3.005575058716044, 'num_boost_round': 413}. Best is trial 0 with value: -0.07832794650006403.
# [I 2025-08-17 23:54:36,307] Trial 1 finished with value: -0.08508523191612072 and parameters: {'learning_rate': 0.005318033256270142, 'num_leaves': 63, 'max_depth': 6, 'min_data_in_leaf': 29, 'feature_fraction': 0.17272998688284025, 'bagging_fraction': 0.27336180394137355, 'bagging_freq': 4, 'lambda_l1': 2.6237821581611893, 'lambda_l2': 2.1597250932105787, 'num_boost_round': 287}. Best is trial 1 with value: -0.08508523191612072.
# [I 2025-08-17 23:54:36,606] Trial 2 finished with value: -0.10165143982728986 and parameters: {'learning_rate': 0.03126143958203108, 'num_leaves': 22, 'max_depth': 3, 'min_data_in_leaf': 43, 'feature_fraction': 0.28242799368681437, 'bagging_fraction': 0.5140703845572054, 'bagging_freq': 2, 'lambda_l1': 2.571172192068058, 'lambda_l2': 2.9620728443102124, 'num_boost_round': 213}. Best is trial 2 with value: -0.10165143982728986.
# [I 2025-08-17 23:54:36,931] Trial 3 finished with value: -0.10546827917897167 and parameters: {'learning_rate': 0.030860579740535368, 'num_leaves': 24, 'max_depth': 2, 'min_data_in_leaf': 96, 'feature_fraction': 0.4862528132298237, 'bagging_fraction': 0.5233589392465845, 'bagging_freq': 4, 'lambda_l1': 0.48836057003191935, 'lambda_l2': 3.4211651325607844, 'num_boost_round': 332}. Best is trial 3 with value: -0.10546827917897167.
# [I 2025-08-17 23:54:37,248] Trial 4 finished with value: -0.1066133142780335 and parameters: {'learning_rate': 0.007206848764305203, 'num_leaves': 40, 'max_depth': 2, 'min_data_in_leaf': 92, 'feature_fraction': 0.20351199264000677, 'bagging_fraction': 0.46500891374159276, 'bagging_freq': 4, 'lambda_l1': 2.600340105889054, 'lambda_l2': 2.7335513967163982, 'num_boost_round': 255}. Best is trial 4 with value: -0.1066133142780335.
# [I 2025-08-17 23:54:37,587] Trial 5 finished with value: -0.09996283474805961 and parameters: {'learning_rate': 0.09129115219600122, 'num_leaves': 53, 'max_depth': 6, 'min_data_in_leaf': 91, 'feature_fraction': 0.3391599915244341, 'bagging_fraction': 0.5687496940092467, 'bagging_freq': 1, 'lambda_l1': 0.979914312095726, 'lambda_l2': 0.22613644455269033, 'num_boost_round': 297}. Best is trial 4 with value: -0.1066133142780335.
# [I 2025-08-17 23:54:37,966] Trial 6 finished with value: -0.10996914737880073 and parameters: {'learning_rate': 0.016019568611465234, 'num_leaves': 29, 'max_depth': 6, 'min_data_in_leaf': 42, 'feature_fraction': 0.2123738038749523, 'bagging_fraction': 0.4170784332632994, 'bagging_freq': 2, 'lambda_l1': 4.010984903770199, 'lambda_l2': 0.3727532183988541, 'num_boost_round': 497}. Best is trial 6 with value: -0.10996914737880073.
# [I 2025-08-17 23:54:38,228] Trial 7 finished with value: -0.09945144910433959 and parameters: {'learning_rate': 0.05054562991054155, 'num_leaves': 25, 'max_depth': 2, 'min_data_in_leaf': 84, 'feature_fraction': 0.38274293753904687, 'bagging_fraction': 0.4916028672163949, 'bagging_freq': 8, 'lambda_l1': 0.3702232586704518, 'lambda_l2': 1.7923286427213632, 'num_boost_round': 234}. Best is trial 6 with value: -0.10996914737880073.
# [I 2025-08-17 23:54:38,522] Trial 8 finished with value: -0.08237710388520532 and parameters: {'learning_rate': 0.06635802485202448, 'num_leaves': 46, 'max_depth': 3, 'min_data_in_leaf': 15, 'feature_fraction': 0.2243929286862649, 'bagging_fraction': 0.33007332881069884, 'bagging_freq': 8, 'lambda_l1': 3.1877873567760657, 'lambda_l2': 4.436063712881633, 'num_boost_round': 342}. Best is trial 6 with value: -0.10996914737880073.
# [I 2025-08-17 23:54:38,900] Trial 9 finished with value: -0.125308565722515 and parameters: {'learning_rate': 0.007154276249073926, 'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 61, 'feature_fraction': 0.40838687198182444, 'bagging_fraction': 0.3975182385457563, 'bagging_freq': 6, 'lambda_l1': 2.137705091792748, 'lambda_l2': 0.12709563372047594, 'num_boost_round': 232}. Best is trial 9 with value: -0.125308565722515.
# ...
# [I 2025-08-18 00:02:55,978] Trial 17 finished with value: -0.06735956654120434 and parameters: {'learning_rate': 0.07068965707420241, 'num_leaves': 44, 'max_depth': 2, 'min_data_in_leaf': 48, 'feature_fraction': 0.32022777832012783, 'bagging_fraction': 0.3730982444721965, 'bagging_freq': 10, 'lambda_l1': 0.4908515732450738, 'lambda_l2': 2.1924327355663973, 'num_boost_round': 384}. Best is trial 7 with value: -0.10545956790077005.
# [I 2025-08-18 00:02:56,468] Trial 18 finished with value: -0.09876085197475784 and parameters: {'learning_rate': 0.051406935907733556, 'num_leaves': 31, 'max_depth': 3, 'min_data_in_leaf': 86, 'feature_fraction': 0.27274311439987087, 'bagging_fraction': 0.4798377164134769, 'bagging_freq': 6, 'lambda_l1': 3.3350919484675408, 'lambda_l2': 0.8479076469387588, 'num_boost_round': 449}. Best is trial 7 with value: -0.10545956790077005.
# [I 2025-08-18 00:02:57,106] Trial 19 finished with value: -0.10440500641774657 and parameters: {'learning_rate': 0.018915137025867522, 'num_leaves': 22, 'max_depth': 4, 'min_data_in_leaf': 88, 'feature_fraction': 0.3651250666290948, 'bagging_fraction': 0.4216266764738027, 'bagging_freq': 8, 'lambda_l1': 4.906565433791467, 'lambda_l2': 4.969213925248544, 'num_boost_round': 258}. Best is trial 7 with value: -0.10545956790077005.
# [I 2025-08-18 00:02:57,863] Trial 20 finished with value: -0.08591810352927239 and parameters: {'learning_rate': 0.014603265597456819, 'num_leaves': 22, 'max_depth': 4, 'min_data_in_leaf': 57, 'feature_fraction': 0.3774152950870597, 'bagging_fraction': 0.40922390018729626, 'bagging_freq': 9, 'lambda_l1': 4.605890786276179, 'lambda_l2': 4.719329010154772, 'num_boost_round': 260}. Best is trial 7 with value: -0.10545956790077005.
# [I 2025-08-18 00:02:58,629] Trial 21 finished with value: -0.09421979149808207 and parameters: {'learning_rate': 0.018431374036174442, 'num_leaves': 26, 'max_depth': 5, 'min_data_in_leaf': 99, 'feature_fraction': 0.44080701751653933, 'bagging_fraction': 0.44851616147340767, 'bagging_freq': 8, 'lambda_l1': 3.6386877683560535, 'lambda_l2': 2.2402788323217266, 'num_boost_round': 256}. Best is trial 7 with value: -0.10545956790077005.
# [I 2025-08-18 00:02:59,459] Trial 22 finished with value: -0.10788153781611809 and parameters: {'learning_rate': 0.011466079350794358, 'num_leaves': 20, 'max_depth': 4, 'min_data_in_leaf': 89, 'feature_fraction': 0.3643199275562074, 'bagging_fraction': 0.5471397936075645, 'bagging_freq': 7, 'lambda_l1': 4.997067470438426, 'lambda_l2': 1.0431493229597275, 'num_boost_round': 238}. Best is trial 22 with value: -0.10788153781611809.
# [I 2025-08-18 00:03:00,117] Trial 23 finished with value: -0.1004751851716916 and parameters: {'learning_rate': 0.012649445556919346, 'num_leaves': 20, 'max_depth': 4, 'min_data_in_leaf': 83, 'feature_fraction': 0.36715931790091305, 'bagging_fraction': 0.5993444219132669, 'bagging_freq': 9, 'lambda_l1': 4.92024108174966, 'lambda_l2': 1.105072325869218, 'num_boost_round': 228}. Best is trial 22 with value: -0.10788153781611809.
# [I 2025-08-18 00:03:00,847] Trial 24 finished with value: -0.09022097451805329 and parameters: {'learning_rate': 0.010266046735814244, 'num_leaves': 18, 'max_depth': 5, 'min_data_in_leaf': 71, 'feature_fraction': 0.44483221157052977, 'bagging_fraction': 0.533490624668879, 'bagging_freq': 7, 'lambda_l1': 4.948505202906833, 'lambda_l2': 0.666141074478378, 'num_boost_round': 273}. Best is trial 22 with value: -0.10788153781611809.
# [I 2025-08-18 00:03:01,325] Trial 25 finished with value: -0.08976116014461952 and parameters: {'learning_rate': 0.022593190408118167, 'num_leaves': 25, 'max_depth': 4, 'min_data_in_leaf': 89, 'feature_fraction': 0.3596088298261668, 'bagging_fraction': 0.5525508325651888, 'bagging_freq': 5, 'lambda_l1': 4.106530480265996, 'lambda_l2': 1.2594943030020482, 'num_boost_round': 240}. Best is trial 22 with value: -0.10788153781611809.
# [I 2025-08-18 00:03:01,915] Trial 26 finished with value: -0.09080450497924011 and parameters: {'learning_rate': 0.012218680511451885, 'num_leaves': 20, 'max_depth': 4, 'min_data_in_leaf': 79, 'feature_fraction': 0.2970114522440144, 'bagging_fraction': 0.48929555801292646, 'bagging_freq': 8, 'lambda_l1': 4.403526613464415, 'lambda_l2': 3.52365973371227, 'num_boost_round': 320}. Best is trial 22 with value: -0.10788153781611809.
# [I 2025-08-18 00:03:02,435] Trial 27 finished with value: -0.10253105483095937 and parameters: {'learning_rate': 0.010556512343793293, 'num_leaves': 29, 'max_depth': 5, 'min_data_in_leaf': 68, 'feature_fraction': 0.40627277946821433, 'bagging_fraction': 0.5973974828448922, 'bagging_freq': 6, 'lambda_l1': 3.595291041109806, 'lambda_l2': 2.5198679341659087, 'num_boost_round': 280}. Best is trial 22 with value: -0.10788153781611809.
# [I 2025-08-18 00:03:02,922] Trial 28 finished with value: -0.11002415424278662 and parameters: {'learning_rate': 0.020040440182463554, 'num_leaves': 23, 'max_depth': 3, 'min_data_in_leaf': 92, 'feature_fraction': 0.26603747201630995, 'bagging_fraction': 0.5563864130306762, 'bagging_freq': 9, 'lambda_l1': 3.0572283202175656, 'lambda_l2': 0.5747313795961354, 'num_boost_round': 211}. Best is trial 28 with value: -0.11002415424278662.
# [I 2025-08-18 00:03:03,395] Trial 29 finished with value: -0.09702538755689466 and parameters: {'learning_rate': 0.02539062676364556, 'num_leaves': 30, 'max_depth': 3, 'min_data_in_leaf': 93, 'feature_fraction': 0.2544029158364445, 'bagging_fraction': 0.5478926911227507, 'bagging_freq': 10, 'lambda_l1': 1.9911860742247596, 'lambda_l2': 0.575854174377719, 'num_boost_round': 204}. Best is trial 28 with value: -0.11002415424278662.
# [I 2025-08-18 00:03:03,988] Trial 30 finished with value: -0.08962760140384396 and parameters: {'learning_rate': 0.008217529383912658, 'num_leaves': 57, 'max_depth': 3, 'min_data_in_leaf': 51, 'feature_fraction': 0.24985416944922287, 'bagging_fraction': 0.5697106509754104, 'bagging_freq': 9, 'lambda_l1': 2.9967011871266718, 'lambda_l2': 0.02525509229621825, 'num_boost_round': 226}. Best is trial 28 with value: -0.11002415424278662.
# [I 2025-08-18 00:03:04,521] Trial 31 finished with value: -0.10420103502424133 and parameters: {'learning_rate': 0.01877082338277225, 'num_leaves': 22, 'max_depth': 4, 'min_data_in_leaf': 85, 'feature_fraction': 0.3561464600002162, 'bagging_fraction': 0.4897403712770982, 'bagging_freq': 8, 'lambda_l1': 4.696239340438964, 'lambda_l2': 1.3710419809587333, 'num_boost_round': 246}. Best is trial 28 with value: -0.11002415424278662.
# [I 2025-08-18 00:03:05,046] Trial 32 finished with value: -0.09481562192338841 and parameters: {'learning_rate': 0.017213932246288824, 'num_leaves': 20, 'max_depth': 3, 'min_data_in_leaf': 89, 'feature_fraction': 0.3110770471047474, 'bagging_fraction': 0.5388891680437452, 'bagging_freq': 9, 'lambda_l1': 3.9951187994037713, 'lambda_l2': 1.8109982274577838, 'num_boost_round': 220}. Best is trial 28 with value: -0.11002415424278662.
# [I 2025-08-18 00:03:05,549] Trial 33 finished with value: -0.10510187314320318 and parameters: {'learning_rate': 0.028513539388163534, 'num_leaves': 24, 'max_depth': 4, 'min_data_in_leaf': 81, 'feature_fraction': 0.4666919596509047, 'bagging_fraction': 0.3045676490669287, 'bagging_freq': 7, 'lambda_l1': 4.372870385873025, 'lambda_l2': 0.7888537765418364, 'num_boost_round': 276}. Best is trial 28 with value: -0.11002415424278662.
# [I 2025-08-18 00:03:06,039] Trial 34 finished with value: -0.09628967060252694 and parameters: {'learning_rate': 0.028555460024819623, 'num_leaves': 26, 'max_depth': 3, 'min_data_in_leaf': 73, 'feature_fraction': 0.44712950668883683, 'bagging_fraction': 0.2598698422532969, 'bagging_freq': 7, 'lambda_l1': 2.929912647884683, 'lambda_l2': 0.6797568302967993, 'num_boost_round': 284}. Best is trial 28 with value: -0.11002415424278662.
# [I 2025-08-18 00:03:06,489] Trial 35 finished with value: -0.08263006376177656 and parameters: {'learning_rate': 0.04374896120903221, 'num_leaves': 23, 'max_depth': 2, 'min_data_in_leaf': 63, 'feature_fraction': 0.45682272646021976, 'bagging_fraction': 0.29824538956976293, 'bagging_freq': 6, 'lambda_l1': 2.2474520980843344, 'lambda_l2': 0.9033210236633162, 'num_boost_round': 216}. Best is trial 28 with value: -0.11002415424278662.
# [I 2025-08-18 00:03:07,183] Trial 36 finished with value: -0.10931281206774446 and parameters: {'learning_rate': 0.005269290825994267, 'num_leaves': 18, 'max_depth': 4, 'min_data_in_leaf': 80, 'feature_fraction': 0.46535211322455083, 'bagging_fraction': 0.2388303087511908, 'bagging_freq': 7, 'lambda_l1': 4.29842791776282, 'lambda_l2': 0.566403547984045, 'num_boost_round': 307}. Best is trial 28 with value: -0.11002415424278662.
# [I 2025-08-18 00:03:07,823] Trial 37 finished with value: -0.10260007101957636 and parameters: {'learning_rate': 0.005227043285068041, 'num_leaves': 17, 'max_depth': 3, 'min_data_in_leaf': 27, 'feature_fraction': 0.17172545924533567, 'bagging_fraction': 0.21066014789029536, 'bagging_freq': 5, 'lambda_l1': 3.7149670841206284, 'lambda_l2': 0.3096198189728804, 'num_boost_round': 367}. Best is trial 28 with value: -0.11002415424278662.
# [I 2025-08-18 00:03:08,403] Trial 38 finished with value: -0.11251227355219012 and parameters: {'learning_rate': 0.00633928004727658, 'num_leaves': 19, 'max_depth': 2, 'min_data_in_leaf': 95, 'feature_fraction': 0.29061455242504436, 'bagging_fraction': 0.24659231586128558, 'bagging_freq': 9, 'lambda_l1': 2.869149570132461, 'lambda_l2': 0.4445598280832612, 'num_boost_round': 308}. Best is trial 38 with value: -0.11251227355219012.
# [I 2025-08-18 00:03:09,133] Trial 39 finished with value: -0.10060042400095119 and parameters: {'learning_rate': 0.006266777962512479, 'num_leaves': 19, 'max_depth': 6, 'min_data_in_leaf': 94, 'feature_fraction': 0.28674035735918435, 'bagging_fraction': 0.23771445303136807, 'bagging_freq': 3, 'lambda_l1': 2.898549889378205, 'lambda_l2': 0.44975829709440796, 'num_boost_round': 312}. Best is trial 38 with value: -0.11251227355219012.
# [I 2025-08-18 00:03:09,811] Trial 40 finished with value: -0.09885397199807885 and parameters: {'learning_rate': 0.006388454517229343, 'num_leaves': 63, 'max_depth': 5, 'min_data_in_leaf': 95, 'feature_fraction': 0.24081123908738813, 'bagging_fraction': 0.24005233946181662, 'bagging_freq': 10, 'lambda_l1': 2.568185926614055, 'lambda_l2': 0.004726191278937142, 'num_boost_round': 326}. Best is trial 38 with value: -0.11251227355219012.
# [I 2025-08-18 00:03:10,307] Trial 41 finished with value: -0.10804699740063003 and parameters: {'learning_rate': 0.008312125294805373, 'num_leaves': 18, 'max_depth': 2, 'min_data_in_leaf': 96, 'feature_fraction': 0.27485299159750215, 'bagging_fraction': 0.2833703567068837, 'bagging_freq': 9, 'lambda_l1': 3.3925896182407977, 'lambda_l2': 1.1107791978370671, 'num_boost_round': 297}. Best is trial 38 with value: -0.11251227355219012.
# [I 2025-08-18 00:03:10,837] Trial 42 finished with value: -0.10139528716867804 and parameters: {'learning_rate': 0.008597536986848594, 'num_leaves': 16, 'max_depth': 2, 'min_data_in_leaf': 95, 'feature_fraction': 0.19680619413309353, 'bagging_fraction': 0.28420306848025, 'bagging_freq': 9, 'lambda_l1': 3.388509526589786, 'lambda_l2': 1.1921130887038123, 'num_boost_round': 298}. Best is trial 38 with value: -0.11251227355219012.
# [I 2025-08-18 00:03:11,343] Trial 43 finished with value: -0.09993554701093094 and parameters: {'learning_rate': 0.006392171941014888, 'num_leaves': 19, 'max_depth': 2, 'min_data_in_leaf': 90, 'feature_fraction': 0.2655171878222837, 'bagging_fraction': 0.24986595623141325, 'bagging_freq': 10, 'lambda_l1': 2.738535652890348, 'lambda_l2': 0.33865863918981987, 'num_boost_round': 299}. Best is trial 38 with value: -0.11251227355219012.
# [I 2025-08-18 00:03:12,006] Trial 44 finished with value: -0.10675890298227192 and parameters: {'learning_rate': 0.005089687095638513, 'num_leaves': 21, 'max_depth': 2, 'min_data_in_leaf': 97, 'feature_fraction': 0.28935403081933037, 'bagging_fraction': 0.2752502540594851, 'bagging_freq': 9, 'lambda_l1': 3.9188152760606423, 'lambda_l2': 0.5967947204078469, 'num_boost_round': 331}. Best is trial 38 with value: -0.11251227355219012.
# [I 2025-08-18 00:03:12,654] Trial 45 finished with value: -0.0833471455101652 and parameters: {'learning_rate': 0.008717737559664178, 'num_leaves': 28, 'max_depth': 2, 'min_data_in_leaf': 37, 'feature_fraction': 0.2281894311652683, 'bagging_fraction': 0.22738232179020754, 'bagging_freq': 8, 'lambda_l1': 3.176456776883614, 'lambda_l2': 1.0767316140385303, 'num_boost_round': 351}. Best is trial 38 with value: -0.11251227355219012.
# [I 2025-08-18 00:03:13,294] Trial 46 finished with value: -0.10736855866721731 and parameters: {'learning_rate': 0.0074672335083600895, 'num_leaves': 18, 'max_depth': 3, 'min_data_in_leaf': 92, 'feature_fraction': 0.3065237112330354, 'bagging_fraction': 0.3343093967346392, 'bagging_freq': 10, 'lambda_l1': 2.3610117557575174, 'lambda_l2': 1.5045713168154409, 'num_boost_round': 266}. Best is trial 38 with value: -0.11251227355219012.
# [I 2025-08-18 00:03:14,024] Trial 47 finished with value: -0.10661720875682448 and parameters: {'learning_rate': 0.005854469475161762, 'num_leaves': 16, 'max_depth': 3, 'min_data_in_leaf': 86, 'feature_fraction': 0.4754949415140075, 'bagging_fraction': 0.31724917005760395, 'bagging_freq': 4, 'lambda_l1': 4.6331379909192965, 'lambda_l2': 2.9264500732924827, 'num_boost_round': 245}. Best is trial 38 with value: -0.11251227355219012.
# [I 2025-08-18 00:03:14,530] Trial 48 finished with value: -0.09531669260845763 and parameters: {'learning_rate': 0.009652405549905582, 'num_leaves': 24, 'max_depth': 2, 'min_data_in_leaf': 77, 'feature_fraction': 0.19603510618216677, 'bagging_fraction': 0.22315690495833662, 'bagging_freq': 9, 'lambda_l1': 4.131459282635047, 'lambda_l2': 0.27708780074551603, 'num_boost_round': 291}. Best is trial 38 with value: -0.11251227355219012.
# [I 2025-08-18 00:03:15,209] Trial 49 finished with value: -0.10385148013312909 and parameters: {'learning_rate': 0.0075289130328729, 'num_leaves': 42, 'max_depth': 3, 'min_data_in_leaf': 98, 'feature_fraction': 0.2778333566608199, 'bagging_fraction': 0.2640788789753643, 'bagging_freq': 8, 'lambda_l1': 3.363527911835, 'lambda_l2': 0.47493639746688837, 'num_boost_round': 340}. Best is trial 38 with value: -0.11251227355219012.
#  ridge alpha: 0.01000, val corr: 0.09592
#  ridge alpha: 0.01743, val corr: 0.09592
#  ridge alpha: 0.03039, val corr: 0.09593
#  ridge alpha: 0.05298, val corr: 0.09593
#  ridge alpha: 0.09237, val corr: 0.09593
#  ridge alpha: 0.16103, val corr: 0.09593
#  ridge alpha: 0.28072, val corr: 0.09594
#  ridge alpha: 0.48939, val corr: 0.09595
#  ridge alpha: 0.85317, val corr: 0.09597
#  ridge alpha: 1.48735, val corr: 0.09600
#  ridge alpha: 2.59294, val corr: 0.09605
#  ridge alpha: 4.52035, val corr: 0.09615
#  ridge alpha: 7.88046, val corr: 0.09631
#  ridge alpha: 13.73824, val corr: 0.09658
#  ridge alpha: 23.95027, val corr: 0.09704
#  ridge alpha: 41.75319, val corr: 0.09779
#  ridge alpha: 72.78954, val corr: 0.09899
#  ridge alpha: 126.89610, val corr: 0.10087
#  ridge alpha: 221.22163, val corr: 0.10369
#  ridge alpha: 385.66204, val corr: 0.10765
#  ridge alpha: 672.33575, val corr: 0.11261
#  ridge alpha: 1172.10230, val corr: 0.11776
#  ridge alpha: 2043.35972, val corr: 0.12187
#  ridge alpha: 3562.24789, val corr: 0.12420
#  ridge alpha: 6210.16942, val corr: 0.12502
#  ridge alpha: 10826.36734, val corr: 0.12507
#  ridge alpha: 18873.91822, val corr: 0.12488
#  ridge alpha: 32903.44562, val corr: 0.12468
#  ridge alpha: 57361.52510, val corr: 0.12452
#  ridge alpha: 100000.00000, val corr: 0.12442
# Best ridge alpha: 10826.36734, val corr: 0.12507
# validation dataset correlation:0.1250741627139793

# %%
# further fine-tuning the ridge regression regularization parameter
ensemble.fit_ridge(X_train, y_train, X_val, y_val, range(6000, 15000, 500))
# Out:
#  ridge alpha: 6000.00000, val corr: 0.12500
#  ridge alpha: 6500.00000, val corr: 0.12505
#  ridge alpha: 7000.00000, val corr: 0.12508
#  ridge alpha: 7500.00000, val corr: 0.12509
#  ridge alpha: 8000.00000, val corr: 0.12510
#  ridge alpha: 8500.00000, val corr: 0.12510
#  ridge alpha: 9000.00000, val corr: 0.12510
#  ridge alpha: 9500.00000, val corr: 0.12510
#  ridge alpha: 10000.00000, val corr: 0.12509
#  ridge alpha: 10500.00000, val corr: 0.12508
#  ridge alpha: 11000.00000, val corr: 0.12507
#  ridge alpha: 11500.00000, val corr: 0.12506
#  ridge alpha: 12000.00000, val corr: 0.12505
#  ridge alpha: 12500.00000, val corr: 0.12503
#  ridge alpha: 13000.00000, val corr: 0.12502
#  ridge alpha: 13500.00000, val corr: 0.12501
#  ridge alpha: 14000.00000, val corr: 0.12500
#  ridge alpha: 14500.00000, val corr: 0.12498
# Best ridge alpha: 8500.00000, val corr: 0.12510

# %%
ensemble.refit_full(df_reduced.drop(columns='label'), df_reduced['label'])

y_test_pred = ensemble.predict(df_reduced_test)
y_test_pred_pd = pd.Series(y_test_pred, name = 'prediction')
y_test_pred_pd.index = df_test.index
y_test_pred_pd.to_csv('../data/output/submission4.csv')
# Out:
# Refitting model 1/20 on full data...
# Refitting model 2/20 on full data...
# Refitting model 3/20 on full data...
# Refitting model 4/20 on full data...
# Refitting model 5/20 on full data...
# Refitting model 6/20 on full data...
# Refitting model 7/20 on full data...
# Refitting model 8/20 on full data...
# Refitting model 9/20 on full data...
# Refitting model 10/20 on full data...
# Refitting model 11/20 on full data...
# Refitting model 12/20 on full data...
# Refitting model 13/20 on full data...
# Refitting model 14/20 on full data...
# Refitting model 15/20 on full data...
# Refitting model 16/20 on full data...
# Refitting model 17/20 on full data...
# Refitting model 18/20 on full data...
# Refitting model 19/20 on full data...
# Refitting model 20/20 on full data...
